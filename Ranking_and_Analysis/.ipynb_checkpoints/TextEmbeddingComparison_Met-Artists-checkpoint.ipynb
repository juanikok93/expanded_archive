# %% [markdown]
# # Multilingual Sentence Encoder simmilarity comparison between Met-Corpus and 50 Colombian Contemporary Artists Keywords
#
# This notebook takes the MetMuseum 100 Keywords obtained from the `Scraping` and `Text` folders, and compares them to the keywords obtained by running the `Keyword_Extractor_EN-ES` notebook on text scrapped from each contemporary artist website and Instagram account. I used the [Multilingual Universal Sentence Encoder](https://www.tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa) because originally was designed for text in english and chinese, later for english and spanish, and as such multilingual embedding is useful as allows word embedding without using separate models for each language.
#
# It then makes a ranking of the artists based on who has the highest similarity values to all keywords, and to the 30 most similar keywords. These two parameters are taken into account given how the range of values to the overall collection is quite narrow, thus including a second parameter can lessen the influence of a decimal difference.
#
# Have to be careful about the specific versions of Tensorflow and sentencepiece programs. There are newer versions by Google to the [MUSE](https://www.tensorflow.org/hub/tutorials/semantic_similarity_with_tf_hub_universal_encoder) model, but this one took long enough to work, so I'll stick with it for now.

# %%
import codecs
import glob
import logging
import os
import pprint
import re
import pickle
import multiprocessing
import nltk
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from nltk.corpus import stopwords
from nltk import word_tokenize, pos_tag
from nltk.stem import WordNetLemmatizer

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Setting up GUSE

# %% [markdown]
# *IMPORTANT*
#
# The compatible library versions:
#
# `tensorflow and tensorflow-gpu == 1.13.1`
#
# `tf-sentencepiece == 0.1.81`
#
# `tensorflow-hub == 0.7.0`
#
# Is recommended to run it this notebook in a new environment, as it requires these very specific library versions

# %%
#latest Tensorflow that supports sentencepiece is 1.13.1
#In case you want to uninstall your current tensorflow version
# !pip uninstall --quiet --yes tensorflow
# !pip uninstall --quiet --yes tensorflow-gpu

# %%
#@title Setup Environment
# !pip install --quiet tensorflow-gpu==1.13.1
# !pip install --quiet tensorflow==1.13.1
# !pip install --quiet tensorflow-hub==0.7.0
# !pip install --quiet bokeh
# !pip install --quiet tf-sentencepiece==0.1.81
# !pip install --quiet simpleneighbors
# !pip install --quiet tqdm

# %% [markdown]
# ### Imports

# %%
#@title Setup common imports and functions
import bokeh
import bokeh.models
import bokeh.plotting
import numpy as np
import os
import pandas as pd
import tensorflow as tf
import tensorflow_hub as hub
import tf_sentencepiece  # Not used directly but needed to import TF ops.
import sklearn.metrics.pairwise

from simpleneighbors import SimpleNeighbors
from tqdm import tqdm
from tqdm import trange
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# The 16-language multilingual module is the default but feel free to pick others from the list and compare the results.

# %%
module_url = 'https://tfhub.dev/google/universal-sentence-encoder-multilingual/1'  

#@param ['https://tfhub.dev/google/universal-sentence-encoder-multilingual/1', 'https://tfhub.dev/google/universal-sentence-encoder-multilingual-large/1', 'https://tfhub.dev/google/universal-sentence-encoder-xling-many/1']

# Set up graph.
g = tf.Graph()
with g.as_default():
  text_input = tf.placeholder(dtype=tf.string, shape=[None])
  multiling_embed = hub.Module(module_url)
  embedded_text = multiling_embed(text_input)
  init_op = tf.group([tf.global_variables_initializer(), tf.tables_initializer()])
g.finalize()

# Initialize session.
session = tf.Session(graph=g)
session.run(init_op)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/control_flow_ops.py:3632: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING: Logging before flag parsing goes to stderr.
# W1007 23:39:40.599957 140207048439616 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/control_flow_ops.py:3632: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I1007 23:39:45.843727 140207048439616 saver.py:1483] Saver not created because there are no variables in the graph to restore

# %% [markdown]
# ### Text Lists
#
# *texts* is a list containing the Metcorpus keywords.
#
# The *artist_keywords* come in a pickle file as a dictionary, varying from 10 to 20 keywords. The amount of keywords does not seem to affect the overall position in the ranking, as both first and last spots are 20 keyword-long artists, and you have some 10 keyword long artist towards the end (it happened with a previous trial that just having less words in a string makes it work better, but since each term is individual it does not affect much.

# %%
import pickle
artist_keywords = pickle.load(open("/storage/keywords_artistas_tfidf.pkl", 'rb'))
artist_keywords
# Out:
# {'adalbertocalvogonzalez_artista': ['serie',
#   'asedio',
#   'reducido',
#   'paisaje',
#   'papel',
#   'paso',
#   'velocidad',
#   'universos',
#   'trabajo',
#   'surrealismo',
#   'representaciones',
#   'pintura',
#   'pieza',
#   'parte',
#   'nacrílico',
#   'lenguajes',
#   'graffiti',
#   'futurismo',
#   'formal',
#   'dibujo'],
#  'agustinalallana': ['indicio',
#   'último',
#   'íntimo',
#   'época',
#   'área',
#   'zona',
#   'yai',
#   'xvi',
#   'wisuya',
#   'vínculos',
#   'vínculo',
#   'voluntad',
#   'viviendas',
#   'vital',
#   'visión',
#   'virtud',
#   'vida',
#   'verdor',
#   'vasijas',
#   'varias'],
#  'alequint': ['vida',
#   'vez',
#   'verlos',
#   've',
#   'universales',
#   'todas',
#   'tipo',
#   'sociedad',
#   'sistema',
#   'sentencias',
#   'semejante',
#   'segunda',
#   'retratos',
#   'restringirlas',
#   'respuesta',
#   'rescatar',
#   'reparador',
#   'rendirse',
#   'regla',
#   'reconocer'],
#  'alexandra_mccormick_artista': ['madeja',
#   'patrimonio',
#   'oficina',
#   'minuta',
#   'medellín',
#   'llantas',
#   'invertido',
#   'intangible',
#   'impresión',
#   'fenómeno',
#   'útil',
#   'época',
#   'árbol',
#   'zapato',
#   'volverse',
#   'volumen',
#   'vive',
#   'vitrales',
#   'vital',
#   'visualizo'],
#  'aliriocc': ['urbano',
#   'tejido',
#   'metal',
#   'material',
#   'hogar',
#   'habitar',
#   'fotocopias',
#   'espacio',
#   'escultura',
#   'cuerpofotografía',
#   'cotidiano',
#   'contenido',
#   'color'],
#  'andres_moreno_hoffmannn': ['ópticos',
#   'ángulos',
#   'visualizar',
#   'visuales',
#   'vislumbrar',
#   'visitantes',
#   'vez',
#   'variante',
#   'vale',
#   'vacío',
#   'universos',
#   'trayectoria',
#   'traduce',
#   'titulada',
#   'titula',
#   'tierra',
#   'tiempos',
#   'teórica',
#   'territorios',
#   'terrenal'],
#  'anibaldo081': ['dibujo',
#   'íntimo',
#   'paisaje',
#   'nubes',
#   'naturaleza',
#   'mixtos',
#   'medios',
#   'instalación',
#   'historia',
#   'esquemático',
#   'cielo',
#   'carbón'],
#  'aparissio': ['video',
#   'historia',
#   'década',
#   'conceptos',
#   'órgano',
#   'xx',
#   'vueltas',
#   'vuela',
#   'voz',
#   'vivir',
#   'visualidad',
#   'vista',
#   'visité',
#   'visible',
#   'vilem',
#   'viento',
#   'vidrio',
#   'vemos',
#   'velocidad',
#   'valiosa'],
#  'burningflags': ['fotografía',
#   'vivo',
#   'vinilo',
#   'serigrafia',
#   'publicaciones',
#   'presentación',
#   'musica',
#   'modulación',
#   'mezcla',
#   'impresiones',
#   'experimental',
#   'entropía',
#   'discos'],
#  'camilabarretohoyos': ['procesos',
#   'nueva',
#   'manera',
#   'imagen',
#   'género',
#   'christian',
#   'únicamente',
#   'yace',
#   'xx',
#   'viviana',
#   'visual',
#   'vibraciones',
#   'verónica',
#   'vehículos',
#   'vehículo',
#   'valor',
#   'vacío',
#   'uribe',
#   'umaña',
#   'triana'],
#  'camilacostalzate': ['vuelve',
#   'volver',
#   'vive',
#   'vice',
#   'viaje',
#   'vez',
#   'ver',
#   'vallejo',
#   'vacío',
#   'unidos',
#   'típicos',
#   'turístico',
#   'transformando',
#   'transforman',
#   'trabajando',
#   'textura',
#   'texto',
#   'terminó',
#   'surge',
#   'sueño'],
#  'carolina_diaz_g': ['íntimo',
#   'televisión',
#   'soliloquio',
#   'romanticismo',
#   'personal',
#   'novela',
#   'instalación',
#   'escultura',
#   'discursos',
#   'catástrofe',
#   'amorosos'],
#  'catalinajaramilloquijano': ['usando',
#   'muchas',
#   'hombre',
#   'gritos',
#   'femeninas',
#   'diccionarios',
#   'compendio',
#   'bebé',
#   'abstracción',
#   'únicamente',
#   'íntimo',
#   'weinrich',
#   'vértigo',
#   'vuelven',
#   'volver',
#   'vivieron',
#   'vinculados',
#   'viaje',
#   'vestigio',
#   'verdadero'],
#  'colectivomonomero': ['china',
#   'superficies',
#   'popular',
#   'pintura',
#   'hecho',
#   'fin',
#   'falso',
#   'estética',
#   'estudio',
#   'escultura',
#   'desfases',
#   'cosas',
#   'consumismo',
#   'comercio',
#   'calidad',
#   'baja'],
#  'crila_regina': ['digital',
#   'video',
#   'televisión',
#   'soap',
#   'romántico',
#   'programas',
#   'popular',
#   'pixel',
#   'opera',
#   'drama',
#   'cultura',
#   'bit',
#   'arte',
#   'animación'],
#  'dacunat': ['vanitas',
#   'realismo',
#   'nubes',
#   'negro',
#   'muerte',
#   'loom',
#   'hiperrealismo',
#   'gloom',
#   'dibujo',
#   'condena',
#   'blanco'],
#  'ejelejalea': ['mapa',
#   'único',
#   'zonas',
#   'xenofobia',
#   'verdadero',
#   'veracruz',
#   'velasco',
#   'universales',
#   'turno',
#   'tríptico',
#   'trazos',
#   'trazo',
#   'trayecto',
#   'tradiciones',
#   'trabajar',
#   'todas',
#   'titulada',
#   'tiempos',
#   'texto',
#   'tela'],
#  'estebanl_lopez_e': ['urbano',
#   'social',
#   'rocas',
#   'pájaros',
#   'pintura',
#   'monumentos',
#   'fotografía',
#   'expresión',
#   'dibujo',
#   'cotidiano',
#   'capturar',
#   'arquitectura'],
#  'faaloon': ['arte',
#   'vivo',
#   'sonoro',
#   'presentación',
#   'performance',
#   'objeto',
#   'electrónica',
#   'digital',
#   'conexiones',
#   'circuitos',
#   'arduino'],
#  'federicopuyo': ['vive',
#   'virtud',
#   'usada',
#   'través',
#   'trabajo',
#   'ser',
#   'sentimientos',
#   'semejanza',
#   'prima',
#   'presentado',
#   'planeta',
#   'persona',
#   'parte',
#   'orgánica',
#   'nadie',
#   'mundo',
#   'mismo',
#   'materia',
#   'madura',
#   'madera'],
#  'felipeuribemejia': ['hombre',
#   'pescaditos',
#   'oro',
#   'monedas',
#   'gesto',
#   'úrsula',
#   'vicioso',
#   'vez',
#   'verdad',
#   'vendía',
#   'tres',
#   'trabajar',
#   'terrible',
#   'sueña',
#   'sucesivamente',
#   'sino',
#   'simple',
#   'serie',
#   'sergio',
#   'sentido'],
#  'felipezapataz4': ['violencia',
#   'postcolonial',
#   'pinturas',
#   'instalacion',
#   'hegemonico',
#   'fisica',
#   'estetica',
#   'digitalmente',
#   'conexiones',
#   'conceptuales',
#   'acumulacion'],
#  'fernandaluzavendano': ['vieron',
#   're',
#   'óleo',
#   'verdades',
#   'utópico',
#   'utópica',
#   'utopía',
#   'utilización',
#   'urbanos',
#   'urbano',
#   'tránsito',
#   'trabajo',
#   'sociedad',
#   'situ',
#   'sirve',
#   'san',
#   'saco',
#   'ruina',
#   'respectivamente',
#   'remodelación'],
#  'gabrielhernandezserrato': ['viajes',
#   'territorio',
#   'realidad',
#   'pintura',
#   'mítico',
#   'juventud',
#   'gorgona',
#   'fuente',
#   'fabricada',
#   'dibujos',
#   'dibujo',
#   'construido',
#   'archipiélago',
#   'antillas'],
#  'guarnizo_david': ['alemania',
#   'índice',
#   'árboles',
#   'árbol',
#   'yendo',
#   'weibel',
#   'vulnerables',
#   'volátil',
#   'vivimos',
#   'viviendas',
#   'visual',
#   'visión',
#   'visible',
#   'viajero',
#   'versiones',
#   'versalles',
#   'verdes',
#   'ver',
#   'venecia',
#   'vamos'],
#  'haymuchasanas': ['nación',
#   'jardín',
#   'liberación',
#   'juego',
#   'frente',
#   'último',
#   'íntimo',
#   'visuales',
#   'visual',
#   'vistos',
#   'vista',
#   'vie',
#   'verano',
#   'vender',
#   'vegetales',
#   'vacío',
#   'vacacionar',
#   'vacacional',
#   'usualmente',
#   'usos'],
#  'jpuribem': ['plaza',
#   'pictórico',
#   'humana',
#   'españa',
#   'camino',
#   'vista',
#   'violentos',
#   'vida',
#   'vez',
#   'verdades',
#   'vende',
#   'variación',
#   'valentía',
#   'tono',
#   'tipología',
#   'tener',
#   'techo',
#   'teatro',
#   'taxonomía',
#   'tampoco'],
#  'juansebastianrosillo': ['quimeras',
#   'álbum',
#   'virtual',
#   'varias',
#   'tatuajes',
#   'sábado',
#   'sonido',
#   'show',
#   'serigrafía',
#   'serigrafias',
#   'rock',
#   'punk',
#   'perfil',
#   'pañoletas',
#   'orden',
#   'nuevo',
#   'nlino',
#   'nen',
#   'negación',
#   'n58cm'],
#  'klauslundi': ['proyecto',
#   'trabajo',
#   'trabajando',
#   'todavi',
#   'territorio',
#   'tener',
#   'superposiciones',
#   'sigue',
#   'significa',
#   'sica',
#   'serie',
#   'ritos',
#   'reflejan',
#   'referirse',
#   'recorrido',
#   'querido',
#   'pronto',
#   'pretensión',
#   'photoespana_',
#   'perrxs'],
#  'layosandres': ['temas',
#   'medellín',
#   'último',
#   'íntimo',
#   'young',
#   'working',
#   'with',
#   'who',
#   'which',
#   'vuelven',
#   'volverás',
#   'vivida',
#   'visual',
#   'vio',
#   'vieron',
#   'vice',
#   'veterinaria',
#   'versiones',
#   'versa',
#   'unparalleled'],
#  'mauriciojaramilloartista': ['urbano',
#   'ruina',
#   'naturaleza',
#   'instalación',
#   'estructuras',
#   'escultura',
#   'dimensión',
#   'dibujo',
#   'ciudad',
#   'carbón',
#   'arquitectura',
#   'abstracto'],
#  'mayacorredorr': ['vorágine',
#   'valientes',
#   'umbilical',
#   'publicaciones',
#   'paisajes',
#   'intimidad',
#   'ilustración',
#   'dibujo',
#   'destino',
#   'cordón',
#   'color',
#   'ciclo'],
#  'namejiam': ['recorridos',
#   'méxico',
#   'mapa',
#   'impresión',
#   'huella',
#   'historia',
#   'gráfica',
#   'grabado',
#   'fragmentos',
#   'atlas',
#   'arqueología'],
#  'natalia_castillo_rincon': ['viaje',
#   'techo',
#   'observad',
#   'maleta',
#   'madera',
#   'conocido',
#   'acción',
#   'última',
#   'yuly',
#   'yorgelis',
#   'vuelve',
#   'vivos',
#   'vivo',
#   'vivió',
#   'vista',
#   'vidrio',
#   'ved',
#   'vea',
#   'vasos',
#   'usa'],
#  'nclsbarrera': ['vinilo',
#   'viejos',
#   'sonidos',
#   'rectángulo',
#   'querer',
#   'new',
#   'less',
#   'día',
#   'únicos',
#   'único',
#   'únicas',
#   'únicamente',
#   'zen',
#   'xxi',
#   'vuelve',
#   'vueltas',
#   'volver',
#   'volumen',
#   'vista',
#   'viendo'],
#  'ojedaenel.lente': ['urbano',
#   'serendipia',
#   'repetición',
#   'líneas',
#   'geometría',
#   'fotografía',
#   'estructura',
#   'encuentro',
#   'edificios',
#   'composición',
#   'abstracto'],
#  'rocio_pardo_e': ['videoarte',
#   'vacío',
#   'transistor',
#   'sonido',
#   'ruido',
#   'instalación',
#   'frecuencia',
#   'experimental',
#   'escultura',
#   'análogo'],
#  'sebastian_fonnegra': ['vive',
#   'visuales',
#   'universidad',
#   'trabaja',
#   'tercer',
#   'temáticas',
#   'sueños',
#   'sebastián',
#   'salones',
#   'residencia',
#   'regionales',
#   'recientemente',
#   'publicado',
#   'publicaciones',
#   'psicoanálisis',
#   'predilección',
#   'posesión',
#   'plásticos',
#   'parque',
#   'palabra'],
#  'sergiogalvis.art': ['técnicas',
#   'viscosidad',
#   'ver',
#   'vacío',
#   'uso',
#   'tiempo',
#   'textura',
#   'tejido',
#   'soldadura',
#   'significativo',
#   'siento',
#   'ser',
#   'rigidez',
#   'resultado',
#   'restar',
#   'resaltar',
#   'repetición',
#   'reflexionar',
#   'recurso',
#   'recurro'],
#  'soniarojaspez': ['siempre',
#   'sensación',
#   'materia',
#   'jamás',
#   'estonia',
#   'días',
#   'devenir',
#   'comienza',
#   'año',
#   'única',
#   'zone',
#   'zarpó',
#   'víctimas',
#   'vía',
#   'vuelven',
#   'vivencias',
#   'viven',
#   'videos',
#   'video',
#   'verbal'],
#  'sophiaprietov': ['tatuajes',
#   'serigrafía',
#   'serigrafias',
#   'rock',
#   'oscuridad',
#   'impresiones',
#   'fuego',
#   'diseño',
#   'cuchillos',
#   'camisetas'],
#  'vicentavictoriagomez': ['vida',
#   'lección',
#   'vídeo',
#   'voz',
#   'vivo',
#   'vientos',
#   'tránsito',
#   'través',
#   'transgredir',
#   'tiempo',
#   'templanza',
#   'suelen',
#   'soliloquio',
#   'sillas',
#   'silencio',
#   'siente',
#   'serialidad',
#   'rosa',
#   'rojo',
#   'rodean'],
#  'villamilyvillamil': ['tejido',
#   'sed',
#   'popular',
#   'pintura',
#   'patrón',
#   'ornamento',
#   'naturaleza',
#   'montañas',
#   'illustración',
#   'color'],
#  'catalinaortiz1065': ['represent',
#   'packaging',
#   'little',
#   'home',
#   'book',
#   'year',
#   'work',
#   'women',
#   'within',
#   'white',
#   'wears',
#   'wanted',
#   'vehicle',
#   'vast',
#   'used',
#   'us',
#   'unfolding',
#   'underwear',
#   'typographic',
#   'translating'],
#  'danielalopezp': ['worldwide',
#   'unique',
#   'travel',
#   'ships',
#   'sells',
#   'research',
#   'process',
#   'portfolio',
#   'pieces',
#   'photography',
#   'pedro',
#   'online',
#   'obsession',
#   'nature',
#   'name',
#   'materials',
#   'main',
#   'made',
#   'lópez',
#   'love'],
#  'feliperomero30': ['bush',
#   'avoid',
#   'armed',
#   'youth',
#   'years',
#   'worship',
#   'whether',
#   'waters',
#   'watching',
#   'visual',
#   'villages',
#   'victims',
#   'valid',
#   'usually',
#   'usual',
#   'uses',
#   'unto',
#   'undetermined',
#   'two',
#   'transits'],
#  'juan_covelli': ['mapping',
#   'forever',
#   'dimension',
#   'cet',
#   'away',
#   'édouard',
#   'åse',
#   'zkm',
#   'zeroes',
#   'year',
#   'word',
#   'within',
#   'widespread',
#   'western',
#   'welcome',
#   'web',
#   'weave',
#   'volume',
#   'visiting',
#   'visit'],
#  'juancortes79': ['juan',
#   'wounds',
#   'without',
#   'warlike',
#   'virtual',
#   'violence',
#   'villegas',
#   'vietnam',
#   'updated',
#   'unpredictable',
#   'unleashed',
#   'unfolding',
#   'understand',
#   'typical',
#   'turning',
#   'turned',
#   'trunks',
#   'trips',
#   'trees',
#   'treatment'],
#  'oldnewflesh': ['culture',
#   'coffee',
#   'workshop',
#   'upon',
#   'sort',
#   'sol',
#   'shopping',
#   'sees',
#   'see',
#   'proper',
#   'noise',
#   'morning',
#   'love',
#   'bed',
#   'yi',
#   'wrote',
#   'written',
#   'write',
#   'world',
#   'works'],
#  'silvanuchis': ['visual',
#   'sunset',
#   'remains',
#   'photography',
#   'light',
#   'glowing',
#   'flowers',
#   'diary',
#   'delicate',
#   'chromatic'],
#  'susanaordonezartista': ['territory',
#   'sweet',
#   'sugarcane',
#   'socialite',
#   'sculpture',
#   'meterial',
#   'handcarved',
#   'guns',
#   'concrete',
#   'carve'],
#  'vanessanietoromero': ['perhaps',
#   'bones',
#   'pillowcase',
#   'organs',
#   'intervention',
#   'household',
#   'gray',
#   'written',
#   'write',
#   'worships',
#   'works',
#   'working',
#   'within',
#   'weeks',
#   'weapons',
#   'weapon',
#   'vulnerability',
#   'votive',
#   'various',
#   'variations'],
#  'vivianabtroya': ['future',
#   'writing',
#   'work',
#   'whisperings',
#   'wherever',
#   'watching',
#   'watch',
#   'wall',
#   'wait',
#   'voices',
#   'visitor',
#   'video',
#   'users',
#   'unwittingly',
#   'underlying',
#   'transcribe',
#   'toilets',
#   'tiny',
#   'three',
#   'think']}

# %%
texts = ['first', 'uninterruptedly', 'circulating', 'later', 'time', 'tragically', 'postponed', 'hiatus', 'untimely', 
         'delayed', 'protracted', 'premature', 'exhausting', 'dissatisfied', 'monopolized', 'portrait', 'mademoiselle', 
         'madame', 'monsieur', 'saint', 'martyr', 'early', 'museum', 'christ', 'period', 'figure', 'nude', 'androgynous', 
         'posture', 'work', 'collaboration', 'drafts', 'cartoonist', 'miniaturist', 'versatile', 'printmaker', 'mediocre', 
         'speculating', 'style', 'manner', 'idiom', 'classic', 'mannerism', 'madonna', 'trends', 'vocabulary', 'peculiarity',
         'characteristic', 'undeniably', 'quintassentially', 'art', 'timeline', 'secrecy', 'society', 'ethnographical', 
         'international', 'jewelry', 'archaeology', 'rarities',  'gold', 'drawing', 'century', 'collection', 'artist', 
         'painter', 'etcher', 'prinmaker', 'inventor', 'copyist', 'precocious', 'collaborator', 'improbably', 'uninspired',
         'confident', 'ambidiextrous', 'muralist', 'painting', 'unquestionably', 'masterpiece', 'picture', 'imitator',
         'rethinking', 'magisterial', 'dislike', 'design',  'pattern', 'geometrical', 'layout', 'scheme', 'structurally', 
         'ornamentation', 'composition', 'repeat', 'chasing', 'elaboration', 'floral']

# %%
#just in case you need a list of the names of the artists here it is
for k in artist_keywords:
    print(k)
# Out:
# adalbertocalvogonzalez_artista
# agustinalallana
# alequint
# alexandra_mccormick_artista
# aliriocc
# andres_moreno_hoffmannn
# anibaldo081
# aparissio
# burningflags
# camilabarretohoyos
# camilacostalzate
# carolina_diaz_g
# catalinajaramilloquijano
# colectivomonomero
# crila_regina
# dacunat
# ejelejalea
# estebanl_lopez_e
# faaloon
# federicopuyo
# felipeuribemejia
# felipezapataz4
# fernandaluzavendano
# gabrielhernandezserrato
# guarnizo_david
# haymuchasanas
# jpuribem
# juansebastianrosillo
# klauslundi
# layosandres
# mauriciojaramilloartista
# mayacorredorr
# namejiam
# natalia_castillo_rincon
# nclsbarrera
# ojedaenel.lente
# rocio_pardo_e
# sebastian_fonnegra
# sergiogalvis.art
# soniarojaspez
# sophiaprietov
# vicentavictoriagomez
# villamilyvillamil
# catalinaortiz1065
# danielalopezp
# feliperomero30
# juan_covelli
# juancortes79
# oldnewflesh
# silvanuchis
# susanaordonezartista
# vanessanietoromero
# vivianabtroya

# %% [markdown]
# #### Embedding of each artist list in a separate variable

# %%
MethEmb = session.run(embedded_text, feed_dict={text_input: texts})

#obtains the embeddings in variables with the format emb_dictionarykey

namespace = globals()
for k in artist_keywords:
    namespace['emb_%s' % k] = session.run(embedded_text, feed_dict={text_input: artist_keywords[k]})

# %% [markdown]
# #### Variable that determines the similarity of each word pair, originally from MUSE

# %%
def visualize_similarity(embeddings_1, embeddings_2, labels_1, labels_2,):
    
    assert len(embeddings_1) == len(labels_1)
    assert len(embeddings_2) == len(labels_2)

  # arccos based text similarity (Yang et al. 2019; Cer et al. 2019)
    sim = 1 - np.arccos(sklearn.metrics.pairwise.cosine_similarity(embeddings_1,embeddings_2))/np.pi
    
    embeddings_1_col, embeddings_2_col, sim_col = [], [], []
    for i in range(len(embeddings_1)):
        for j in range(len(embeddings_2)):
            embeddings_1_col.append(labels_1[i])
            embeddings_2_col.append(labels_2[j])
            sim_col.append(sim[i][j])
    df = pd.DataFrame(zip(embeddings_1_col, embeddings_2_col, sim_col),
                columns=['embeddings_1', 'embeddings_2', 'sim'])
    return df

# %% [markdown]
# #### Similarity obtaining the values from the prior embedding

# %%
for k in artist_keywords:
    namespace['df_%s' % k] = visualize_similarity(MethEmb, namespace['emb_%s' % k], texts, artist_keywords[k]) 

# df_simm = visualize_similarity(MethEmb, Key1emb, texts, AltargerelDelgerama)
# dfart2 = visualize_similarity(MethEmb, Key2emb, texts, AnaCurk)

# %% [markdown]
# *List of top simmilarities between collection-artist words*
#
# replace `df_artistname` in order to see the top words for a particular artist

# %%
# Prueba para ver si funciona la similitud. Escogi a esta artista ya que sabia de antemano que tenia la coincidencia
# flowers - floral, que se refleja con similitud de 0.80

df_agustinalallana.sort_values(by=['sim'],ascending=False).head(35)
# Out:
#          embeddings_1 embeddings_2       sim
# 63               time        época  0.780992
# 151        protracted       verdor  0.772422
# 363            period        época  0.753094
# 123          untimely        época  0.732093
# 768          timeline        época  0.731801
# 181        exhausting       verdor  0.731308
# 375            figure      indicio  0.719905
# 590            manner     voluntad  0.718293
# 586            manner       verdor  0.716051
# 918           century        época  0.714054
# 782           secrecy       íntimo  0.704769
# 196      dissatisfied       verdor  0.704374
# 91          postponed       verdor  0.698047
# 76         tragically       verdor  0.697645
# 392              nude       íntimo  0.697095
# 67               time         vida  0.696290
# 150        protracted      indicio  0.694811
# 16    uninterruptedly       verdor  0.694279
# 442              work         vida  0.692581
# 555       speculating      indicio  0.691745
# 814    ethnographical        fauna  0.691463
# 155        protracted     voluntad  0.690257
# 271          monsieur       verdor  0.689496
# 185        exhausting     voluntad  0.688979
# 127          untimely         vida  0.688426
# 1400          chasing     voluntad  0.687855
# 1036       precocious       verdor  0.687371
# 1246          dislike       verdor  0.686591
# 257            madame       íntimo  0.686421
# 121          untimely       verdor  0.684642
# 1103        confident       virtud  0.683753
# 1396          chasing       verdor  0.683371
# 705    characteristic      indicio  0.682973
# 600             idiom      indicio  0.682870
# 126          untimely        vital  0.682862

# %% [markdown]
# ### Values that stores the mean and median of all the similarity column

# %%
simmil_art_mean = []
simmil_art_median = []

#finds and stores in above list the mean in each dataframe

for k in artist_keywords:
    simmil_art_mean.append(namespace['df_%s' % k]['sim'].mean())
    
#finds and stores in above list the median in each dataframe

for k in artist_keywords:
    simmil_art_median.append(namespace['df_%s' % k]['sim'].median())

# %%
#Both mean and median values have around the same range of min and max, so is unnecesary to include both in calculation
print(min(simmil_art_mean))
print(max(simmil_art_mean))

print(min(simmil_art_median))
print(max(simmil_art_median))
# Out:
# 0.6111212555939952
# 0.6275568507993833
# 0.6091335713863373
# 0.6257765293121338

# %% [markdown]
# ### Value that stores the mean of the top 30 words (closeness to top 5%)

# %%
#I just used average as it captured a wider variation between min - max values.

simmil_30 = []

for k in artist_keywords:
    simmil_30.append(namespace['df_%s' % k]['sim'].sort_values(ascending=False).head(30).mean())

# %%
print(min(simmil_30))
print(max(simmil_30))
# Out:
# 0.6833540479342143
# 0.746122153600057

# %% [markdown]
# Getting artist names and keywords in a list so as to fit them in a dictionary to build the DataFrame

# %%
nombres_artistas =  []
palabras_key = []

for k in artist_keywords:
    nombres_artistas.append(k)
    palabras_key.append(artist_keywords[k])    
    
ArtistTextDict = {'Artist':nombres_artistas,'Keywords':palabras_key,'Average Simil to Text Core':simmil_art_mean,'Median Simil to Text Core':simmil_art_median, 'Simil top 30':simmil_30}

# %% [markdown]
# ## General Dataframe with keywords extracted using TF-IDF

# %%
df = pd.DataFrame(ArtistTextDict) 
df
# Out:
#                             Artist  \
# 0   adalbertocalvogonzalez_artista
# 1                  agustinalallana
# 2                         alequint
# 3      alexandra_mccormick_artista
# 4                         aliriocc
# 5          andres_moreno_hoffmannn
# 6                      anibaldo081
# 7                        aparissio
# 8                     burningflags
# 9               camilabarretohoyos
# 10                camilacostalzate
# 11                 carolina_diaz_g
# 12        catalinajaramilloquijano
# 13               colectivomonomero
# 14                    crila_regina
# 15                         dacunat
# 16                      ejelejalea
# 17                estebanl_lopez_e
# 18                         faaloon
# 19                    federicopuyo
# 20                felipeuribemejia
# 21                  felipezapataz4
# 22             fernandaluzavendano
# 23         gabrielhernandezserrato
# 24                  guarnizo_david
# 25                   haymuchasanas
# 26                        jpuribem
# 27            juansebastianrosillo
# 28                      klauslundi
# 29                     layosandres
# 30        mauriciojaramilloartista
# 31                   mayacorredorr
# 32                        namejiam
# 33         natalia_castillo_rincon
# 34                     nclsbarrera
# 35                 ojedaenel.lente
# 36                   rocio_pardo_e
# 37              sebastian_fonnegra
# 38                sergiogalvis.art
# 39                   soniarojaspez
# 40                   sophiaprietov
# 41            vicentavictoriagomez
# 42               villamilyvillamil
# 43               catalinaortiz1065
# 44                   danielalopezp
# 45                  feliperomero30
# 46                    juan_covelli
# 47                    juancortes79
# 48                     oldnewflesh
# 49                     silvanuchis
# 50            susanaordonezartista
# 51              vanessanietoromero
# 52                   vivianabtroya
#
#                                              Keywords  \
# 0   [asedio, formal, dibujo, serie, representacion...
# 1   [indicio, verdor, íntimo, época, fauna, volunt...
# 2   [rendirse, reconocer, cuerpo, enigma, tipo, re...
# 3   [madeja, invertido, época, imagen, fenómeno, t...
# 4   [urbano, tejido, metal, material, hogar, habit...
# 5   [ópticos, ángulos, visualizar, visuales, vislu...
# 6   [dibujo, íntimo, paisaje, nubes, naturaleza, m...
# 7   [video, historia, década, conceptos, órgano, x...
# 8   [fotografía, vivo, vinilo, serigrafia, publica...
# 9   [procesos, nueva, manera, imagen, género, chri...
# 10  [vuelve, volver, vive, vice, viaje, vez, ver, ...
# 11  [íntimo, televisión, soliloquio, romanticismo,...
# 12  [usando, muchas, hombre, gritos, femeninas, di...
# 13  [china, superficies, popular, pintura, hecho, ...
# 14  [digital, video, televisión, soap, romántico, ...
# 15  [vanitas, realismo, nubes, negro, muerte, loom...
# 16  [mapa, único, zonas, xenofobia, verdadero, ver...
# 17  [urbano, social, rocas, pájaros, pintura, monu...
# 18  [arte, vivo, sonoro, presentación, performance...
# 19  [vive, virtud, usada, través, trabajo, ser, se...
# 20  [vicioso, sucesivamente, sentido, portada, ter...
# 21  [violencia, postcolonial, pinturas, instalacio...
# 22  [vieron, re, óleo, verdades, utópico, utópica,...
# 23  [viajes, territorio, realidad, pintura, mítico...
# 24  [habitar, arte, territorio, tiempo, volátil, v...
# 25  [visual, íntimo, juego, arte, vida, nación, li...
# 26  [plaza, pictórico, humana, españa, camino, vis...
# 27  [quimeras, álbum, virtual, varias, tatuajes, s...
# 28  [íntimos, pretensión, forma, querido, tener, s...
# 29  [temas, medellín, último, íntimo, young, worki...
# 30  [urbano, ruina, naturaleza, instalación, estru...
# 31  [vorágine, valientes, umbilical, publicaciones...
# 32  [recorridos, méxico, mapa, impresión, huella, ...
# 33  [viaje, techo, observad, maleta, madera, conoc...
# 34  [vinilo, viejos, sonidos, rectángulo, querer, ...
# 35  [urbano, serendipia, repetición, líneas, geome...
# 36  [videoarte, vacío, transistor, sonido, ruido, ...
# 37  [vive, visuales, universidad, trabaja, tercer,...
# 38  [técnicas, viscosidad, ver, vacío, uso, tiempo...
# 39  [siempre, sensación, materia, jamás, estonia, ...
# 40  [tatuajes, serigrafía, serigrafias, rock, oscu...
# 41  [vida, lección, vídeo, voz, vivo, vientos, trá...
# 42  [tejido, sed, popular, pintura, patrón, orname...
# 43  [represent, packaging, little, home, book, yea...
# 44  [worldwide, unique, travel, ships, sells, rese...
# 45  [visual, usual, worship, armed, youth, police,...
# 46  [mapping, forever, dimension, cet, away, édoua...
# 47  [juan, wounds, without, warlike, virtual, viol...
# 48  [culture, coffee, workshop, upon, sort, sol, s...
# 49  [visual, sunset, remains, photography, light, ...
# 50  [territory, sweet, sugarcane, socialite, sculp...
# 51  [perhaps, bones, pillowcase, organs, intervent...
# 52  [future, writing, work, whisperings, wherever,...
#
#     Average Simil to Text Core  Median Simil to Text Core  Simil top 30
# 0                     0.620029                   0.617029      0.724822
# 1                     0.623766                   0.622640      0.707438
# 2                     0.620684                   0.619929      0.725793
# 3                     0.627455                   0.625081      0.732312
# 4                     0.615642                   0.613963      0.684970
# 5                     0.615792                   0.613789      0.712518
# 6                     0.623523                   0.621949      0.712278
# 7                     0.612967                   0.610762      0.693233
# 8                     0.614018                   0.611329      0.696313
# 9                     0.616646                   0.613646      0.714643
# 10                    0.617097                   0.614641      0.725048
# 11                    0.615337                   0.613621      0.683354
# 12                    0.615812                   0.612568      0.710360
# 13                    0.620565                   0.618578      0.706865
# 14                    0.614557                   0.611404      0.707235
# 15                    0.624115                   0.621312      0.707029
# 16                    0.613621                   0.611426      0.721017
# 17                    0.619750                   0.616408      0.729160
# 18                    0.613211                   0.609695      0.696384
# 19                    0.620549                   0.620075      0.725794
# 20                    0.626211                   0.622392      0.739599
# 21                    0.617585                   0.615347      0.712804
# 22                    0.613670                   0.611795      0.720535
# 23                    0.620313                   0.617470      0.730696
# 24                    0.619821                   0.618136      0.723979
# 25                    0.615441                   0.613038      0.709384
# 26                    0.618575                   0.616840      0.705801
# 27                    0.612308                   0.611774      0.704894
# 28                    0.627557                   0.625777      0.718135
# 29                    0.618472                   0.615883      0.723723
# 30                    0.616513                   0.613497      0.715143
# 31                    0.620671                   0.617413      0.723574
# 32                    0.619655                   0.617505      0.704329
# 33                    0.613353                   0.610548      0.704519
# 34                    0.616001                   0.614694      0.706774
# 35                    0.617803                   0.617024      0.725537
# 36                    0.615279                   0.614473      0.691109
# 37                    0.611121                   0.609134      0.702080
# 38                    0.619997                   0.616620      0.746122
# 39                    0.615322                   0.613578      0.712801
# 40                    0.611863                   0.611141      0.700871
# 41                    0.614871                   0.613604      0.711859
# 42                    0.617694                   0.615472      0.718019
# 43                    0.622480                   0.620690      0.723487
# 44                    0.614844                   0.611797      0.709714
# 45                    0.620522                   0.618834      0.702245
# 46                    0.618624                   0.616973      0.709352
# 47                    0.616783                   0.614235      0.724937
# 48                    0.620753                   0.619195      0.718140
# 49                    0.622938                   0.620901      0.702922
# 50                    0.623115                   0.620609      0.696696
# 51                    0.615152                   0.612295      0.716514
# 52                    0.619406                   0.615575      0.741180

# %% [markdown]
# *Checking if there is a change between the general ranking and the top 30 word*

# %%
df[['Average Simil to Text Core','Artist']].sort_values(by=['Average Simil to Text Core'], ascending=False).head(10)
# Out:
#     Average Simil to Text Core                       Artist
# 28                    0.627557                   klauslundi
# 3                     0.627455  alexandra_mccormick_artista
# 20                    0.626211             felipeuribemejia
# 15                    0.624115                      dacunat
# 1                     0.623766              agustinalallana
# 6                     0.623523                  anibaldo081
# 50                    0.623115         susanaordonezartista
# 49                    0.622938                  silvanuchis
# 43                    0.622480            catalinaortiz1065
# 48                    0.620753                  oldnewflesh

# %%
df[['Simil top 30','Artist']].sort_values(by=['Simil top 30'], ascending=False).head(10)
# Out:
#     Simil top 30                       Artist
# 38      0.746122             sergiogalvis.art
# 52      0.741180                vivianabtroya
# 20      0.739599             felipeuribemejia
# 3       0.732312  alexandra_mccormick_artista
# 23      0.730696      gabrielhernandezserrato
# 17      0.729160             estebanl_lopez_e
# 19      0.725794                 federicopuyo
# 2       0.725793                     alequint
# 35      0.725537              ojedaenel.lente
# 10      0.725048             camilacostalzate

# %% [markdown]
# Indeed, different artists feature in both lists

# %% [markdown]
# *Making a ranking for each*

# %%
df['Score Mean TextCorpus'] = df['Average Simil to Text Core'].rank(ascending = 0)
df['Score Top30'] = df['Simil top 30'].rank(ascending = 0)
df['Total Text Score'] = df['Score Mean TextCorpus'] + df['Score Top30'] 
df.sort_values(by='Total Text Score')
#df.drop('Text Rank',axis=1, inplace=True)
df
# Out:
#                             Artist  \
# 0   adalbertocalvogonzalez_artista
# 1                  agustinalallana
# 2                         alequint
# 3      alexandra_mccormick_artista
# 4                         aliriocc
# 5          andres_moreno_hoffmannn
# 6                      anibaldo081
# 7                        aparissio
# 8                     burningflags
# 9               camilabarretohoyos
# 10                camilacostalzate
# 11                 carolina_diaz_g
# 12        catalinajaramilloquijano
# 13               colectivomonomero
# 14                    crila_regina
# 15                         dacunat
# 16                      ejelejalea
# 17                estebanl_lopez_e
# 18                         faaloon
# 19                    federicopuyo
# 20                felipeuribemejia
# 21                  felipezapataz4
# 22             fernandaluzavendano
# 23         gabrielhernandezserrato
# 24                  guarnizo_david
# 25                   haymuchasanas
# 26                        jpuribem
# 27            juansebastianrosillo
# 28                      klauslundi
# 29                     layosandres
# 30        mauriciojaramilloartista
# 31                   mayacorredorr
# 32                        namejiam
# 33         natalia_castillo_rincon
# 34                     nclsbarrera
# 35                 ojedaenel.lente
# 36                   rocio_pardo_e
# 37              sebastian_fonnegra
# 38                sergiogalvis.art
# 39                   soniarojaspez
# 40                   sophiaprietov
# 41            vicentavictoriagomez
# 42               villamilyvillamil
# 43               catalinaortiz1065
# 44                   danielalopezp
# 45                  feliperomero30
# 46                    juan_covelli
# 47                    juancortes79
# 48                     oldnewflesh
# 49                     silvanuchis
# 50            susanaordonezartista
# 51              vanessanietoromero
# 52                   vivianabtroya
#
#                                              Keywords  \
# 0   [asedio, formal, dibujo, serie, representacion...
# 1   [indicio, verdor, íntimo, época, fauna, volunt...
# 2   [rendirse, reconocer, cuerpo, enigma, tipo, re...
# 3   [madeja, invertido, época, imagen, fenómeno, t...
# 4   [urbano, tejido, metal, material, hogar, habit...
# 5   [ópticos, ángulos, visualizar, visuales, vislu...
# 6   [dibujo, íntimo, paisaje, nubes, naturaleza, m...
# 7   [video, historia, década, conceptos, órgano, x...
# 8   [fotografía, vivo, vinilo, serigrafia, publica...
# 9   [procesos, nueva, manera, imagen, género, chri...
# 10  [vuelve, volver, vive, vice, viaje, vez, ver, ...
# 11  [íntimo, televisión, soliloquio, romanticismo,...
# 12  [usando, muchas, hombre, gritos, femeninas, di...
# 13  [china, superficies, popular, pintura, hecho, ...
# 14  [digital, video, televisión, soap, romántico, ...
# 15  [vanitas, realismo, nubes, negro, muerte, loom...
# 16  [mapa, único, zonas, xenofobia, verdadero, ver...
# 17  [urbano, social, rocas, pájaros, pintura, monu...
# 18  [arte, vivo, sonoro, presentación, performance...
# 19  [vive, virtud, usada, través, trabajo, ser, se...
# 20  [vicioso, sucesivamente, sentido, portada, ter...
# 21  [violencia, postcolonial, pinturas, instalacio...
# 22  [vieron, re, óleo, verdades, utópico, utópica,...
# 23  [viajes, territorio, realidad, pintura, mítico...
# 24  [habitar, arte, territorio, tiempo, volátil, v...
# 25  [visual, íntimo, juego, arte, vida, nación, li...
# 26  [plaza, pictórico, humana, españa, camino, vis...
# 27  [quimeras, álbum, virtual, varias, tatuajes, s...
# 28  [íntimos, pretensión, forma, querido, tener, s...
# 29  [temas, medellín, último, íntimo, young, worki...
# 30  [urbano, ruina, naturaleza, instalación, estru...
# 31  [vorágine, valientes, umbilical, publicaciones...
# 32  [recorridos, méxico, mapa, impresión, huella, ...
# 33  [viaje, techo, observad, maleta, madera, conoc...
# 34  [vinilo, viejos, sonidos, rectángulo, querer, ...
# 35  [urbano, serendipia, repetición, líneas, geome...
# 36  [videoarte, vacío, transistor, sonido, ruido, ...
# 37  [vive, visuales, universidad, trabaja, tercer,...
# 38  [técnicas, viscosidad, ver, vacío, uso, tiempo...
# 39  [siempre, sensación, materia, jamás, estonia, ...
# 40  [tatuajes, serigrafía, serigrafias, rock, oscu...
# 41  [vida, lección, vídeo, voz, vivo, vientos, trá...
# 42  [tejido, sed, popular, pintura, patrón, orname...
# 43  [represent, packaging, little, home, book, yea...
# 44  [worldwide, unique, travel, ships, sells, rese...
# 45  [visual, usual, worship, armed, youth, police,...
# 46  [mapping, forever, dimension, cet, away, édoua...
# 47  [juan, wounds, without, warlike, virtual, viol...
# 48  [culture, coffee, workshop, upon, sort, sol, s...
# 49  [visual, sunset, remains, photography, light, ...
# 50  [territory, sweet, sugarcane, socialite, sculp...
# 51  [perhaps, bones, pillowcase, organs, intervent...
# 52  [future, writing, work, whisperings, wherever,...
#
#     Average Simil to Text Core  Median Simil to Text Core  Simil top 30  \
# 0                     0.620029                   0.617029      0.724822
# 1                     0.623766                   0.622640      0.707438
# 2                     0.620684                   0.619929      0.725793
# 3                     0.627455                   0.625081      0.732312
# 4                     0.615642                   0.613963      0.684970
# 5                     0.615792                   0.613789      0.712518
# 6                     0.623523                   0.621949      0.712278
# 7                     0.612967                   0.610762      0.693233
# 8                     0.614018                   0.611329      0.696313
# 9                     0.616646                   0.613646      0.714643
# 10                    0.617097                   0.614641      0.725048
# 11                    0.615337                   0.613621      0.683354
# 12                    0.615812                   0.612568      0.710360
# 13                    0.620565                   0.618578      0.706865
# 14                    0.614557                   0.611404      0.707235
# 15                    0.624115                   0.621312      0.707029
# 16                    0.613621                   0.611426      0.721017
# 17                    0.619750                   0.616408      0.729160
# 18                    0.613211                   0.609695      0.696384
# 19                    0.620549                   0.620075      0.725794
# 20                    0.626211                   0.622392      0.739599
# 21                    0.617585                   0.615347      0.712804
# 22                    0.613670                   0.611795      0.720535
# 23                    0.620313                   0.617470      0.730696
# 24                    0.619821                   0.618136      0.723979
# 25                    0.615441                   0.613038      0.709384
# 26                    0.618575                   0.616840      0.705801
# 27                    0.612308                   0.611774      0.704894
# 28                    0.627557                   0.625777      0.718135
# 29                    0.618472                   0.615883      0.723723
# 30                    0.616513                   0.613497      0.715143
# 31                    0.620671                   0.617413      0.723574
# 32                    0.619655                   0.617505      0.704329
# 33                    0.613353                   0.610548      0.704519
# 34                    0.616001                   0.614694      0.706774
# 35                    0.617803                   0.617024      0.725537
# 36                    0.615279                   0.614473      0.691109
# 37                    0.611121                   0.609134      0.702080
# 38                    0.619997                   0.616620      0.746122
# 39                    0.615322                   0.613578      0.712801
# 40                    0.611863                   0.611141      0.700871
# 41                    0.614871                   0.613604      0.711859
# 42                    0.617694                   0.615472      0.718019
# 43                    0.622480                   0.620690      0.723487
# 44                    0.614844                   0.611797      0.709714
# 45                    0.620522                   0.618834      0.702245
# 46                    0.618624                   0.616973      0.709352
# 47                    0.616783                   0.614235      0.724937
# 48                    0.620753                   0.619195      0.718140
# 49                    0.622938                   0.620901      0.702922
# 50                    0.623115                   0.620609      0.696696
# 51                    0.615152                   0.612295      0.716514
# 52                    0.619406                   0.615575      0.741180
#
#     Score Mean TextCorpus  Score Top30  Total Text Score
# 0                    17.0         12.0              29.0
# 1                     5.0         34.0              39.0
# 2                    11.0          8.0              19.0
# 3                     2.0          4.0               6.0
# 4                    36.0         52.0              88.0
# 5                    35.0         27.0              62.0
# 6                     6.0         28.0              34.0
# 7                    50.0         50.0             100.0
# 8                    45.0         49.0              94.0
# 9                    31.0         24.0              55.0
# 10                   29.0         10.0              39.0
# 11                   38.0         53.0              91.0
# 12                   34.0         30.0              64.0
# 13                   13.0         37.0              50.0
# 14                   44.0         35.0              79.0
# 15                    4.0         36.0              40.0
# 16                   47.0         17.0              64.0
# 17                   20.0          6.0              26.0
# 18                   49.0         48.0              97.0
# 19                   14.0          7.0              21.0
# 20                    3.0          3.0               6.0
# 21                   28.0         25.0              53.0
# 22                   46.0         18.0              64.0
# 23                   16.0          5.0              21.0
# 24                   19.0         13.0              32.0
# 25                   37.0         32.0              69.0
# 26                   24.0         39.0              63.0
# 27                   51.0         40.0              91.0
# 28                    1.0         20.0              21.0
# 29                   25.0         14.0              39.0
# 30                   32.0         23.0              55.0
# 31                   12.0         15.0              27.0
# 32                   21.0         42.0              63.0
# 33                   48.0         41.0              89.0
# 34                   33.0         38.0              71.0
# 35                   26.0          9.0              35.0
# 36                   40.0         51.0              91.0
# 37                   53.0         45.0              98.0
# 38                   18.0          1.0              19.0
# 39                   39.0         26.0              65.0
# 40                   52.0         46.0              98.0
# 41                   42.0         29.0              71.0
# 42                   27.0         21.0              48.0
# 43                    9.0         16.0              25.0
# 44                   43.0         31.0              74.0
# 45                   15.0         44.0              59.0
# 46                   23.0         33.0              56.0
# 47                   30.0         11.0              41.0
# 48                   10.0         19.0              29.0
# 49                    8.0         43.0              51.0
# 50                    7.0         47.0              54.0
# 51                   41.0         22.0              63.0
# 52                   22.0          2.0              24.0

# %% [markdown]
# *Attention* MUSE measures SIMILARITY which makes the highest number the closest one. Do not confuse with DISTANCE values,  in which the lowest number would be the most similar.

# %%
df['Rank'] = df['Average Simil to Text Core'].rank(ascending = 0)
df.sort_values(by=['Rank'])#.head(20)
# Out:
#                             Artist  \
# 28                      klauslundi
# 3      alexandra_mccormick_artista
# 20                felipeuribemejia
# 15                         dacunat
# 1                  agustinalallana
# 6                      anibaldo081
# 50            susanaordonezartista
# 49                     silvanuchis
# 43               catalinaortiz1065
# 48                     oldnewflesh
# 2                         alequint
# 31                   mayacorredorr
# 13               colectivomonomero
# 19                    federicopuyo
# 45                  feliperomero30
# 23         gabrielhernandezserrato
# 0   adalbertocalvogonzalez_artista
# 38                sergiogalvis.art
# 24                  guarnizo_david
# 17                estebanl_lopez_e
# 32                        namejiam
# 52                   vivianabtroya
# 46                    juan_covelli
# 26                        jpuribem
# 29                     layosandres
# 35                 ojedaenel.lente
# 42               villamilyvillamil
# 21                  felipezapataz4
# 10                camilacostalzate
# 47                    juancortes79
# 9               camilabarretohoyos
# 30        mauriciojaramilloartista
# 34                     nclsbarrera
# 12        catalinajaramilloquijano
# 5          andres_moreno_hoffmannn
# 4                         aliriocc
# 25                   haymuchasanas
# 11                 carolina_diaz_g
# 39                   soniarojaspez
# 36                   rocio_pardo_e
# 51              vanessanietoromero
# 41            vicentavictoriagomez
# 44                   danielalopezp
# 14                    crila_regina
# 8                     burningflags
# 22             fernandaluzavendano
# 16                      ejelejalea
# 33         natalia_castillo_rincon
# 18                         faaloon
# 7                        aparissio
# 27            juansebastianrosillo
# 40                   sophiaprietov
# 37              sebastian_fonnegra
#
#                                              Keywords  \
# 28  [íntimos, pretensión, forma, querido, tener, s...
# 3   [madeja, invertido, época, imagen, fenómeno, t...
# 20  [vicioso, sucesivamente, sentido, portada, ter...
# 15  [vanitas, realismo, nubes, negro, muerte, loom...
# 1   [indicio, verdor, íntimo, época, fauna, volunt...
# 6   [dibujo, íntimo, paisaje, nubes, naturaleza, m...
# 50  [territory, sweet, sugarcane, socialite, sculp...
# 49  [visual, sunset, remains, photography, light, ...
# 43  [represent, packaging, little, home, book, yea...
# 48  [culture, coffee, workshop, upon, sort, sol, s...
# 2   [rendirse, reconocer, cuerpo, enigma, tipo, re...
# 31  [vorágine, valientes, umbilical, publicaciones...
# 13  [china, superficies, popular, pintura, hecho, ...
# 19  [vive, virtud, usada, través, trabajo, ser, se...
# 45  [visual, usual, worship, armed, youth, police,...
# 23  [viajes, territorio, realidad, pintura, mítico...
# 0   [asedio, formal, dibujo, serie, representacion...
# 38  [técnicas, viscosidad, ver, vacío, uso, tiempo...
# 24  [habitar, arte, territorio, tiempo, volátil, v...
# 17  [urbano, social, rocas, pájaros, pintura, monu...
# 32  [recorridos, méxico, mapa, impresión, huella, ...
# 52  [future, writing, work, whisperings, wherever,...
# 46  [mapping, forever, dimension, cet, away, édoua...
# 26  [plaza, pictórico, humana, españa, camino, vis...
# 29  [temas, medellín, último, íntimo, young, worki...
# 35  [urbano, serendipia, repetición, líneas, geome...
# 42  [tejido, sed, popular, pintura, patrón, orname...
# 21  [violencia, postcolonial, pinturas, instalacio...
# 10  [vuelve, volver, vive, vice, viaje, vez, ver, ...
# 47  [juan, wounds, without, warlike, virtual, viol...
# 9   [procesos, nueva, manera, imagen, género, chri...
# 30  [urbano, ruina, naturaleza, instalación, estru...
# 34  [vinilo, viejos, sonidos, rectángulo, querer, ...
# 12  [usando, muchas, hombre, gritos, femeninas, di...
# 5   [ópticos, ángulos, visualizar, visuales, vislu...
# 4   [urbano, tejido, metal, material, hogar, habit...
# 25  [visual, íntimo, juego, arte, vida, nación, li...
# 11  [íntimo, televisión, soliloquio, romanticismo,...
# 39  [siempre, sensación, materia, jamás, estonia, ...
# 36  [videoarte, vacío, transistor, sonido, ruido, ...
# 51  [perhaps, bones, pillowcase, organs, intervent...
# 41  [vida, lección, vídeo, voz, vivo, vientos, trá...
# 44  [worldwide, unique, travel, ships, sells, rese...
# 14  [digital, video, televisión, soap, romántico, ...
# 8   [fotografía, vivo, vinilo, serigrafia, publica...
# 22  [vieron, re, óleo, verdades, utópico, utópica,...
# 16  [mapa, único, zonas, xenofobia, verdadero, ver...
# 33  [viaje, techo, observad, maleta, madera, conoc...
# 18  [arte, vivo, sonoro, presentación, performance...
# 7   [video, historia, década, conceptos, órgano, x...
# 27  [quimeras, álbum, virtual, varias, tatuajes, s...
# 40  [tatuajes, serigrafía, serigrafias, rock, oscu...
# 37  [vive, visuales, universidad, trabaja, tercer,...
#
#     Average Simil to Text Core  Median Simil to Text Core  Simil top 30  \
# 28                    0.627557                   0.625777      0.718135
# 3                     0.627455                   0.625081      0.732312
# 20                    0.626211                   0.622392      0.739599
# 15                    0.624115                   0.621312      0.707029
# 1                     0.623766                   0.622640      0.707438
# 6                     0.623523                   0.621949      0.712278
# 50                    0.623115                   0.620609      0.696696
# 49                    0.622938                   0.620901      0.702922
# 43                    0.622480                   0.620690      0.723487
# 48                    0.620753                   0.619195      0.718140
# 2                     0.620684                   0.619929      0.725793
# 31                    0.620671                   0.617413      0.723574
# 13                    0.620565                   0.618578      0.706865
# 19                    0.620549                   0.620075      0.725794
# 45                    0.620522                   0.618834      0.702245
# 23                    0.620313                   0.617470      0.730696
# 0                     0.620029                   0.617029      0.724822
# 38                    0.619997                   0.616620      0.746122
# 24                    0.619821                   0.618136      0.723979
# 17                    0.619750                   0.616408      0.729160
# 32                    0.619655                   0.617505      0.704329
# 52                    0.619406                   0.615575      0.741180
# 46                    0.618624                   0.616973      0.709352
# 26                    0.618575                   0.616840      0.705801
# 29                    0.618472                   0.615883      0.723723
# 35                    0.617803                   0.617024      0.725537
# 42                    0.617694                   0.615472      0.718019
# 21                    0.617585                   0.615347      0.712804
# 10                    0.617097                   0.614641      0.725048
# 47                    0.616783                   0.614235      0.724937
# 9                     0.616646                   0.613646      0.714643
# 30                    0.616513                   0.613497      0.715143
# 34                    0.616001                   0.614694      0.706774
# 12                    0.615812                   0.612568      0.710360
# 5                     0.615792                   0.613789      0.712518
# 4                     0.615642                   0.613963      0.684970
# 25                    0.615441                   0.613038      0.709384
# 11                    0.615337                   0.613621      0.683354
# 39                    0.615322                   0.613578      0.712801
# 36                    0.615279                   0.614473      0.691109
# 51                    0.615152                   0.612295      0.716514
# 41                    0.614871                   0.613604      0.711859
# 44                    0.614844                   0.611797      0.709714
# 14                    0.614557                   0.611404      0.707235
# 8                     0.614018                   0.611329      0.696313
# 22                    0.613670                   0.611795      0.720535
# 16                    0.613621                   0.611426      0.721017
# 33                    0.613353                   0.610548      0.704519
# 18                    0.613211                   0.609695      0.696384
# 7                     0.612967                   0.610762      0.693233
# 27                    0.612308                   0.611774      0.704894
# 40                    0.611863                   0.611141      0.700871
# 37                    0.611121                   0.609134      0.702080
#
#     Score Mean TextCorpus  Score Top30  Total Text Score  Rank
# 28                    1.0         20.0              21.0   1.0
# 3                     2.0          4.0               6.0   2.0
# 20                    3.0          3.0               6.0   3.0
# 15                    4.0         36.0              40.0   4.0
# 1                     5.0         34.0              39.0   5.0
# 6                     6.0         28.0              34.0   6.0
# 50                    7.0         47.0              54.0   7.0
# 49                    8.0         43.0              51.0   8.0
# 43                    9.0         16.0              25.0   9.0
# 48                   10.0         19.0              29.0  10.0
# 2                    11.0          8.0              19.0  11.0
# 31                   12.0         15.0              27.0  12.0
# 13                   13.0         37.0              50.0  13.0
# 19                   14.0          7.0              21.0  14.0
# 45                   15.0         44.0              59.0  15.0
# 23                   16.0          5.0              21.0  16.0
# 0                    17.0         12.0              29.0  17.0
# 38                   18.0          1.0              19.0  18.0
# 24                   19.0         13.0              32.0  19.0
# 17                   20.0          6.0              26.0  20.0
# 32                   21.0         42.0              63.0  21.0
# 52                   22.0          2.0              24.0  22.0
# 46                   23.0         33.0              56.0  23.0
# 26                   24.0         39.0              63.0  24.0
# 29                   25.0         14.0              39.0  25.0
# 35                   26.0          9.0              35.0  26.0
# 42                   27.0         21.0              48.0  27.0
# 21                   28.0         25.0              53.0  28.0
# 10                   29.0         10.0              39.0  29.0
# 47                   30.0         11.0              41.0  30.0
# 9                    31.0         24.0              55.0  31.0
# 30                   32.0         23.0              55.0  32.0
# 34                   33.0         38.0              71.0  33.0
# 12                   34.0         30.0              64.0  34.0
# 5                    35.0         27.0              62.0  35.0
# 4                    36.0         52.0              88.0  36.0
# 25                   37.0         32.0              69.0  37.0
# 11                   38.0         53.0              91.0  38.0
# 39                   39.0         26.0              65.0  39.0
# 36                   40.0         51.0              91.0  40.0
# 51                   41.0         22.0              63.0  41.0
# 41                   42.0         29.0              71.0  42.0
# 44                   43.0         31.0              74.0  43.0
# 14                   44.0         35.0              79.0  44.0
# 8                    45.0         49.0              94.0  45.0
# 22                   46.0         18.0              64.0  46.0
# 16                   47.0         17.0              64.0  47.0
# 33                   48.0         41.0              89.0  48.0
# 18                   49.0         48.0              97.0  49.0
# 7                    50.0         50.0             100.0  50.0
# 27                   51.0         40.0              91.0  51.0
# 40                   52.0         46.0              98.0  52.0
# 37                   53.0         45.0              98.0  53.0

# %%
df.set_index('Artist', inplace=True)

# %% [markdown]
# *Saving it to .csv file*

# %%
df.to_csv("colombiartistas_text_simmil.csv", encoding='utf-8')

# %%
textsdict = {'MetMuseum Keywords' : texts}

# %%
dftexts = pd.DataFrame(textsdict) 
dftexts.to_csv("metmuseumkeywords.csv", encoding='utf-8')

# %%
p = df_klauslundi.groupby(by='embeddings_2').mean()
p.sort_values(by='sim', ascending=False)
# Out:
#                       sim
# embeddings_2
# ritos            0.651580
# pretensión       0.638849
# querido          0.636366
# tener            0.634979
# superposiciones  0.632303
# territorio       0.628726
# serie            0.628261
# sigue            0.628021
# recorrido        0.627727
# sica             0.626052
# proyecto         0.624800
# todavi           0.624501
# referirse        0.623199
# trabajo          0.620932
# pronto           0.620326
# trabajando       0.619636
# reflejan         0.617805
# perrxs           0.611525
# photoespana_     0.599961
# significa        0.598735

# %% [markdown]
# # Ranking using Frequency List Keywords

# %% [markdown]
# I also made a ranking using the keywords extracted through frequency list. Although TF-IDF gets better terms, I wanted to see the difference in the final rankings, in order to compare the effectiveness of the MUSE embeddings, and the ranking method in general.

# %%
artist_keywordsc = pickle.load(open("/storage/keywords_artistas_conteo.pkl", 'rb'))
artist_keywordsc
# Out:
# {'adalbertocalvogonzalez_artista': ['serie',
#   'asedio',
#   'paisaje',
#   'reducido',
#   'papel',
#   'paso',
#   'lenguajes',
#   'universos',
#   'desdoblados',
#   'arqueología',
#   'graffiti',
#   'futurismo',
#   'surrealismo',
#   'representaciones',
#   'arqueológicas',
#   'dibujo',
#   'pintura',
#   'alta',
#   'velocidad',
#   'construcción'],
#  'agustinalallana': ['selva',
#   'ser',
#   'hombre',
#   'mundo',
#   'animal',
#   'animales',
#   'tiempo',
#   'gallo',
#   'fauna',
#   'especies',
#   'indígena',
#   'putumayo',
#   'pueblos',
#   'íntima',
#   'través',
#   'así',
#   'frente',
#   'bien',
#   'serie',
#   'región'],
#  'alequint': ['cuerpo',
#   'haciendo',
#   'demás',
#   'pregunta',
#   'tiempo',
#   'después',
#   'celebrar',
#   'mismo',
#   'forma',
#   'balnearios',
#   'sino',
#   'mientras',
#   've',
#   'cuál',
#   'enigma',
#   'detrás',
#   'retratos',
#   'albinos',
#   'fotógrafa',
#   'alejandra'],
#  'alexandra_mccormick_artista': ['luz',
#   'espacio',
#   'lugar',
#   'agua',
#   'imágenes',
#   'dibujos',
#   'papel',
#   'vida',
#   'diapositivas',
#   'superficie',
#   'trabajo',
#   'territorio',
#   'puede',
#   'ver',
#   'relación',
#   'sonido',
#   'algarrobo',
#   'archivador',
#   'imagen',
#   '8'],
#  'aliriocc': ['escultura',
#   'hogar',
#   'habitar',
#   'espacio',
#   'contenido',
#   'material',
#   'metal',
#   'tejido',
#   'urbano',
#   'cotidiano',
#   'cuerpofotografía',
#   'fotocopias',
#   'color'],
#  'andres_moreno_hoffmannn': ['artista',
#   'espacio',
#   'bogotá',
#   'museo',
#   'moreno',
#   'hoffmann',
#   'geometría',
#   'universo',
#   'pinturas',
#   'artistas',
#   'curva',
#   'través',
#   'medio',
#   'arte',
#   'grises',
#   'akashá',
#   'arquitectura',
#   'parecen',
#   'modelos',
#   'andrés'],
#  'anibaldo081': ['dibujo',
#   'naturaleza',
#   'paisaje',
#   'instalación',
#   'cielo',
#   'nubes',
#   'esquemático',
#   'íntimo',
#   'carbón',
#   'medios',
#   'mixtos',
#   'historia'],
#  'aparissio': ['tiempo',
#   'mundo',
#   'imágenes',
#   'reloj',
#   'biblioteca',
#   'ahora',
#   'máquina',
#   'días',
#   'través',
#   'rostro',
#   'hombre',
#   'libro',
#   'memoria',
#   'archivo',
#   'forma',
#   'años',
#   'trabajo',
#   'pincel',
#   'cámara',
#   'escáner'],
#  'burningflags': ['fotografía',
#   'publicaciones',
#   'impresiones',
#   'serigrafia',
#   'discos',
#   'vinilo',
#   'musica',
#   'experimental',
#   'entropía',
#   'modulación',
#   'mezcla',
#   'presentación',
#   'vivo'],
#  'camilabarretohoyos': ['barreto',
#   'textil',
#   'camila',
#   'tiempo',
#   'dispositivo',
#   'obras',
#   'abusaid',
#   'experiencia',
#   'espacio',
#   'pieza',
#   'campos',
#   'fuerza',
#   'christian',
#   'sala',
#   'exposición',
#   'artistas',
#   'hacen',
#   'uso',
#   'forma',
#   'nociones'],
#  'camilacostalzate': ['ciudad',
#   'caminar',
#   'serie',
#   'día',
#   'foto',
#   'tiempo',
#   'miami',
#   'duda',
#   'entonces',
#   'ido',
#   'hispanohablantes',
#   'escoge',
#   'color',
#   'guste',
#   'empieza',
#   'fotografía',
#   'fotógrafa',
#   'islandia',
#   'dolor',
#   'exquisito'],
#  'carolina_diaz_g': ['soliloquio',
#   'discursos',
#   'amorosos',
#   'novela',
#   'romanticismo',
#   'catástrofe',
#   'instalación',
#   'escultura',
#   'televisión',
#   'íntimo',
#   'personal'],
#  'catalinajaramilloquijano': ['libros',
#   'serie',
#   'lugar',
#   'memoria',
#   'dibujos',
#   'objetos',
#   'humo',
#   'partir',
#   'proyecto',
#   'vida',
#   'biblioteca',
#   'colección',
#   'ser',
#   'agua',
#   'trabajo',
#   'existen',
#   'entonces',
#   'flores',
#   'intuición',
#   'trabajos'],
#  'colectivomonomero': ['china',
#   'estudio',
#   'fin',
#   'cosas',
#   'falso',
#   'baja',
#   'calidad',
#   'pintura',
#   'escultura',
#   'hecho',
#   'desfases',
#   'superficies',
#   'estética',
#   'popular',
#   'comercio',
#   'consumismo'],
#  'crila_regina': ['digital',
#   '8',
#   'bit',
#   'pixel',
#   'animación',
#   'video',
#   'cultura',
#   'popular',
#   'drama',
#   'soap',
#   'opera',
#   'romántico',
#   'programas',
#   'televisión',
#   'arte'],
#  'dacunat': ['dibujo',
#   'nubes',
#   'hiperrealismo',
#   'realismo',
#   'blanco',
#   'negro',
#   'vanitas',
#   'muerte',
#   'condena',
#   'loom',
#   'gloom'],
#  'ejelejalea': ['dibujo',
#   'territorio',
#   'bordes',
#   'artista',
#   'susana',
#   'rosario',
#   'dibujos',
#   'norte',
#   'vez',
#   'encuentra',
#   'través',
#   'cordilleras',
#   'tiempo',
#   'mapa',
#   'sino',
#   'propone',
#   'montañas',
#   'mes',
#   'comencé',
#   'trabajar'],
#  'estebanl_lopez_e': ['fotografía',
#   'arquitectura',
#   'monumentos',
#   'dibujo',
#   'pájaros',
#   'pintura',
#   'rocas',
#   'expresión',
#   'cotidiano',
#   'capturar',
#   'urbano',
#   'social'],
#  'faaloon': ['arte',
#   'digital',
#   'sonoro',
#   'electrónica',
#   'circuitos',
#   'presentación',
#   'vivo',
#   'performance',
#   'arduino',
#   'conexiones',
#   'objeto'],
#  'federicopuyo': ['vive',
#   'si',
#   'cada',
#   'persona',
#   'mundo',
#   'nadie',
#   'mismo',
#   'planeta',
#   'ataduras',
#   'madura',
#   'laminados',
#   'lacquer',
#   'trabajo',
#   'aquí',
#   'presentado',
#   'exploración',
#   'experiencia',
#   'humana',
#   'través',
#   'lenguajes'],
#  'felipeuribemejia': ['hombre',
#   'laguna',
#   'libros',
#   'negocio',
#   'pescaditos',
#   'monedas',
#   'oro',
#   'cada',
#   'trabajo',
#   'i',
#   'gesto',
#   'serie',
#   'pinturas',
#   'ilustración',
#   'portada',
#   'libro',
#   'cita',
#   'bob',
#   'dylan',
#   'agenda'],
#  'felipezapataz4': ['pinturas',
#   'digitalmente',
#   'fisica',
#   'estetica',
#   'hegemonico',
#   'acumulacion',
#   'postcolonial',
#   'conexiones',
#   'conceptuales',
#   'instalacion',
#   'violencia'],
#  'fernandaluzavendano': ['través',
#   'proyecto',
#   'cemento',
#   'paisaje',
#   'espacios',
#   'tiempo',
#   'obrero',
#   'pintura',
#   'dorada',
#   'casco',
#   'modernos',
#   'busca',
#   'representar',
#   'partir',
#   'emocionales',
#   'construcción',
#   'vieron',
#   're',
#   'realizado',
#   'galeria'],
#  'gabrielhernandezserrato': ['gorgona',
#   'dibujos',
#   'viajes',
#   'mítico',
#   'construido',
#   'realidad',
#   'fabricada',
#   'territorio',
#   'dibujo',
#   'pintura',
#   'antillas',
#   'archipiélago',
#   'juventud',
#   'fuente'],
#  'guarnizo_david': ['paisaje',
#   'línea',
#   'horizonte',
#   'mediante',
#   'fuji',
#   'naturaleza',
#   'nevado',
#   'pino',
#   'paisajes',
#   'tiempo',
#   'territorios',
#   'través',
#   'territorio',
#   'jardín',
#   'espacio',
#   'habitar',
#   'hombre',
#   'creación',
#   'da',
#   'arte'],
#  'haymuchasanas': ['lugares',
#   'paraíso',
#   'gnomos',
#   'ciudad',
#   'publicación',
#   'tenis',
#   'proyecto',
#   'cálidos',
#   'vacaciones',
#   'movimiento',
#   'ser',
#   'personas',
#   'jardín',
#   'francia',
#   'arte',
#   'nación',
#   'tropical',
#   'david',
#   'hockney',
#   'vida'],
#  'jpuribem': ['rayas',
#   'papel',
#   'si',
#   'recta',
#   'arte',
#   'forma',
#   'calle',
#   'tiempo',
#   'espacio',
#   'venden',
#   'leonel',
#   'curva',
#   'agnes',
#   'martin',
#   'continuas',
#   'historia',
#   'américa',
#   'información',
#   'contable',
#   'reciclado'],
#  'juansebastianrosillo': ['quimeras',
#   'diseño',
#   'evento',
#   'donaciones',
#   'pañoletas',
#   'disponibles',
#   'n58cm',
#   'x',
#   '58cm',
#   'nlino',
#   'algodón',
#   'impresión',
#   'serigrafía',
#   'sonido',
#   'negación',
#   'muro',
#   'orden',
#   'mundial',
#   'hice',
#   'amigas'],
#  'klauslundi': ['perros',
#   'proyecto',
#   'forma',
#   'personal',
#   'lundi',
#   'cercanos',
#   'lenguaje',
#   'todavi',
#   'sigue',
#   'nhe',
#   'trabajando',
#   'libro',
#   'u',
#   'ltimos',
#   '13',
#   'an',
#   'festival',
#   'off',
#   'photoespana_',
#   'participando'],
#  'layosandres': ['andrés',
#   'valentina',
#   'layos',
#   'dibujo',
#   'vida',
#   'artista',
#   'años',
#   'muerte',
#   'parte',
#   'cada',
#   'luz',
#   'dualidad',
#   'juntos',
#   'cuerpos',
#   'muestra',
#   'dibujos',
#   'hace',
#   'animales',
#   'hija',
#   'dos'],
#  'mauriciojaramilloartista': ['dibujo',
#   'carbón',
#   'estructuras',
#   'abstracto',
#   'arquitectura',
#   'ruina',
#   'naturaleza',
#   'ciudad',
#   'dimensión',
#   'urbano',
#   'escultura',
#   'instalación'],
#  'mayacorredorr': ['destino',
#   'valientes',
#   'publicaciones',
#   'paisajes',
#   'ciclo',
#   'vorágine',
#   'ilustración',
#   'cordón',
#   'umbilical',
#   'intimidad',
#   'dibujo',
#   'color'],
#  'namejiam': ['grabado',
#   'gráfica',
#   'impresión',
#   'atlas',
#   'mapa',
#   'historia',
#   'huella',
#   'fragmentos',
#   'recorridos',
#   'arqueología',
#   'méxico'],
#  'natalia_castillo_rincon': ['espacio',
#   'cuerpo',
#   'objetos',
#   'casa',
#   'ser',
#   'm',
#   '1',
#   'lugar',
#   'así',
#   'x',
#   'embargo',
#   'proyecto',
#   'habitar',
#   'mínimo',
#   'cuenta',
#   'ver',
#   'instalación',
#   '2',
#   '3',
#   'podemos'],
#  'nclsbarrera': ['ser',
#   'tiempo',
#   'hacer',
#   'cada',
#   'forma',
#   'vez',
#   'objeto',
#   'puede',
#   'obras',
#   'arte',
#   'producto',
#   'cosas',
#   'si',
#   'bajo',
#   'serie',
#   'acción',
#   'proceso',
#   'obra',
#   'artista',
#   'imagen'],
#  'ojedaenel.lente': ['fotografía',
#   'geometría',
#   'urbano',
#   'serendipia',
#   'encuentro',
#   'composición',
#   'repetición',
#   'abstracto',
#   'edificios',
#   'estructura',
#   'líneas'],
#  'rocio_pardo_e': ['videoarte',
#   'instalación',
#   'escultura',
#   'análogo',
#   'transistor',
#   'ruido',
#   'frecuencia',
#   'experimental',
#   'sonido',
#   'vacío'],
#  'sebastian_fonnegra': ['trabajo',
#   'dibujo',
#   'bogotá',
#   'fotografía',
#   'beca',
#   'artes',
#   'plásticas',
#   'colombia',
#   'otorgada',
#   'premio',
#   'vive',
#   'trabaja',
#   'maestro',
#   'universidad',
#   'nacional',
#   'desarrolla',
#   'diferentes',
#   'medios',
#   'plásticos',
#   'predilección'],
#  'sergiogalvis.art': ['permite',
#   'acero',
#   'material',
#   'técnicas',
#   'consigue',
#   'diversas',
#   'presentaciones',
#   'manipularlo',
#   'distintos',
#   'modos',
#   'experimentación',
#   'recurro',
#   'soldadura',
#   'manipulación',
#   'herramientas',
#   'uso',
#   'abrasivos',
#   'conjunto',
#   'procesos',
#   'metal'],
#  'soniarojaspez': ['tiempo',
#   'medio',
#   'habitantes',
#   'barrio',
#   'lugar',
#   'teppes',
#   'siempre',
#   'paisajes',
#   'personas',
#   'proceso',
#   'diarias',
#   'mundo',
#   'bajo',
#   'jamás',
#   'eternidad',
#   'frustración',
#   'constante',
#   'ser',
#   'memorias',
#   'estonia'],
#  'sophiaprietov': ['tatuajes',
#   'camisetas',
#   'impresiones',
#   'serigrafias',
#   'rock',
#   'cuchillos',
#   'fuego',
#   'diseño',
#   'serigrafía',
#   'oscuridad'],
#  'vicentavictoriagomez': ['vida',
#   'lección',
#   'medios',
#   'plásticos',
#   'trabajo',
#   'morera',
#   'remiendos',
#   'remedios',
#   'templanza',
#   'hilo',
#   'momentos',
#   'línea',
#   'desprendimiento',
#   'corazón',
#   'rojo',
#   'espera',
#   'tiempo',
#   'deshacer',
#   'manos',
#   'negras'],
#  'villamilyvillamil': ['sed',
#   'montañas',
#   'naturaleza',
#   'popular',
#   'ornamento',
#   'illustración',
#   'pintura',
#   'tejido',
#   'patrón',
#   'color'],
#  'catalinaortiz1065': ['emotional',
#   'paper',
#   'drawings',
#   'life',
#   'events',
#   'drawing',
#   'series',
#   'works',
#   'nest',
#   'exhibition',
#   'relationship',
#   'word',
#   'state',
#   'implies',
#   'part',
#   'alphabet',
#   'images',
#   'using',
#   'new',
#   'woman'],
#  'danielalopezp': ['brand',
#   'disco',
#   'rojo',
#   'created',
#   'colombia',
#   'art',
#   'fashion',
#   'photography',
#   'travel',
#   'flowers',
#   'portfolio',
#   'accesories',
#   'collection',
#   'accessories',
#   '2017',
#   'daniela',
#   'lópez',
#   's',
#   'name',
#   'born'],
#  'feliperomero30': ['undocumented',
#   'river',
#   'immigrant',
#   'police',
#   'grave',
#   'force',
#   'legal',
#   'streets',
#   'area',
#   'immigrants',
#   'subdued',
#   'violence',
#   'madrid',
#   'water',
#   'bush',
#   'thing',
#   'something',
#   'status',
#   'can',
#   'transit'],
#  'juan_covelli': ['art',
#   'digital',
#   'new',
#   'space',
#   'exhibition',
#   'will',
#   'objects',
#   'world',
#   're',
#   'technologies',
#   '3d',
#   's',
#   'two',
#   'things',
#   'can',
#   'artworks',
#   'one',
#   'image',
#   'covelli',
#   'archive'],
#  'juancortes79': ['fusarium',
#   'fungus',
#   'life',
#   'way',
#   'laboratory',
#   'science',
#   'field',
#   'whose',
#   'according',
#   's',
#   'entity',
#   'economic',
#   'new',
#   'human',
#   'body',
#   'oxysporum',
#   'international',
#   'center',
#   'cytotoxicity',
#   'advanced'],
#  'oldnewflesh': ['rengifo',
#   'exhibition',
#   'everyday',
#   'like',
#   'kierkegaard',
#   's',
#   'landscapes',
#   'one',
#   'secret',
#   'spaces',
#   'images',
#   'work',
#   'sandra',
#   'project',
#   'søren',
#   'objects',
#   'familiar',
#   'life',
#   'genie',
#   'spyglass'],
#  'silvanuchis': ['visual',
#   'diary',
#   'chromatic',
#   'remains',
#   'flowers',
#   'photography',
#   'delicate',
#   'glowing',
#   'sunset',
#   'light'],
#  'susanaordonezartista': ['sugarcane',
#   'sculpture',
#   'guns',
#   'handcarved',
#   'territory',
#   'meterial',
#   'concrete',
#   'socialite',
#   'sweet',
#   'carve'],
#  'vanessanietoromero': ['acid',
#   'project',
#   'body',
#   'act',
#   'printmaking',
#   'colombia',
#   'women',
#   's',
#   'installation',
#   'prayers',
#   'perhaps',
#   'bones',
#   'skin',
#   'meets',
#   'marks',
#   'violence',
#   'attacks',
#   'violent',
#   'process',
#   'work'],
#  'vivianabtroya': ['time',
#   'people',
#   'waiting',
#   'room',
#   'space',
#   'network',
#   'can',
#   'visitors',
#   'installation',
#   'heat',
#   'real',
#   'security',
#   'world',
#   'inside',
#   'one',
#   'de',
#   'outside',
#   'future',
#   'password',
#   'passwords']}

# %%
MethEmb = session.run(embedded_text, feed_dict={text_input: texts})

#obtains the embeddings in variables with the format emb_dictionarykey

namespace = globals()
for k in artist_keywordsc:
    namespace['embc_%s' % k] = session.run(embedded_text, feed_dict={text_input: artist_keywordsc[k]})

# %%
def visualize_similarity(embeddings_1, embeddings_2, labels_1, labels_2,):
    
    assert len(embeddings_1) == len(labels_1)
    assert len(embeddings_2) == len(labels_2)

  # arccos based text similarity (Yang et al. 2019; Cer et al. 2019)
    sim = 1 - np.arccos(sklearn.metrics.pairwise.cosine_similarity(embeddings_1,embeddings_2))/np.pi
    
    embeddings_1_col, embeddings_2_col, sim_col = [], [], []
    for i in range(len(embeddings_1)):
        for j in range(len(embeddings_2)):
            embeddings_1_col.append(labels_1[i])
            embeddings_2_col.append(labels_2[j])
            sim_col.append(sim[i][j])
    df = pd.DataFrame(zip(embeddings_1_col, embeddings_2_col, sim_col),
                columns=['embeddings_1', 'embeddings_2', 'sim'])
    return df

# %%
for k in artist_keywordsc:
    namespace['dfc_%s' % k] = visualize_similarity(MethEmb, namespace['embc_%s' % k], texts, artist_keywordsc[k])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in arccos
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in arccos
#   import sys

# %%
dfc_haymuchasanas.sort_values(by=['sim'],ascending=False).head(35)
# Out:
#         embeddings_1 embeddings_2       sim
# 1014             art         arte  0.923247
# 1274          artist         arte  0.779730
# 1686          design     proyecto  0.769824
# 626           drafts     proyecto  0.758140
# 170         untimely          ser  0.740667
# 1550  unquestionably          ser  0.736547
# 1294         painter         arte  0.734229
# 970       undeniably          ser  0.734102
# 49       circulating   movimiento  0.718278
# 1766          scheme     proyecto  0.716790
# 1886     elaboration     proyecto  0.715755
# 1534        painting         arte  0.715155
# 1364         copyist  publicación  0.705850
# 1470       confident          ser  0.704312
# 790           manner          ser  0.702728
# 789           manner   movimiento  0.698051
# 99              time         vida  0.696290
# 1071         society     personas  0.695016
# 1574     masterpiece         arte  0.692600
# 599             work         vida  0.692581
# 215       protracted       nación  0.692277
# 1884     elaboration  publicación  0.690733
# 1746          layout     proyecto  0.689666
# 730         mediocre          ser  0.688666
# 470           christ          ser  0.688645
# 179         untimely         vida  0.688426
# 1411    collaborator     personas  0.686790
# 1271          artist     personas  0.684752
# 314         portrait         arte  0.684708
# 124        postponed  publicación  0.684246
# 1214         drawing         arte  0.683030
# 370         monsieur          ser  0.682773
# 654       cartoonist         arte  0.682655
# 795           manner       nación  0.682567
# 1310          etcher          ser  0.681627

# %%
simmilc_art_mean = []
simmilc_art_median = []

#finds and stores in above list the mean in each dataframe

for k in artist_keywordsc:
    simmilc_art_mean.append(namespace['dfc_%s' % k]['sim'].mean())
    
#finds and stores in above list the median in each dataframe

for k in artist_keywordsc:
    simmilc_art_median.append(namespace['dfc_%s' % k]['sim'].median())

# %%
print(min(simmilc_art_mean))
print(max(simmilc_art_mean))

print(min(simmilc_art_median))
print(max(simmilc_art_median))
# Out:
# 0.6045667453979452
# 0.6241151082583449
# 0.6065887212753296
# 0.6219494044780731

# %%
simmil_30c = []

for k in artist_keywordsc:
    simmil_30c.append(namespace['dfc_%s' % k]['sim'].sort_values(ascending=False).head(30).mean())

# %%
print(min(simmil_30c))
print(max(simmil_30c))
# Out:
# 0.6833540260791778
# 0.7692031582196553

# %%
nombres_artistasc =  []
palabras_keyc = []

for k in artist_keywordsc:
    nombres_artistasc.append(k)
    palabras_keyc.append(artist_keywordsc[k])    
    
ArtistTextDictc = {'Artist':nombres_artistasc,'Keywords':palabras_keyc,'Average Simil to Text Core':simmilc_art_mean,'Median Simil to Text Core':simmilc_art_median, 'Simil top 30':simmil_30c}

# %%
dfc = pd.DataFrame(ArtistTextDictc) 
dfc
# Out:
#                             Artist  \
# 0   adalbertocalvogonzalez_artista
# 1                  agustinalallana
# 2                         alequint
# 3      alexandra_mccormick_artista
# 4                         aliriocc
# 5          andres_moreno_hoffmannn
# 6                      anibaldo081
# 7                        aparissio
# 8                     burningflags
# 9               camilabarretohoyos
# 10                camilacostalzate
# 11                 carolina_diaz_g
# 12        catalinajaramilloquijano
# 13               colectivomonomero
# 14                    crila_regina
# 15                         dacunat
# 16                      ejelejalea
# 17                estebanl_lopez_e
# 18                         faaloon
# 19                    federicopuyo
# 20                felipeuribemejia
# 21                  felipezapataz4
# 22             fernandaluzavendano
# 23         gabrielhernandezserrato
# 24                  guarnizo_david
# 25                   haymuchasanas
# 26                        jpuribem
# 27            juansebastianrosillo
# 28                      klauslundi
# 29                     layosandres
# 30        mauriciojaramilloartista
# 31                   mayacorredorr
# 32                        namejiam
# 33         natalia_castillo_rincon
# 34                     nclsbarrera
# 35                 ojedaenel.lente
# 36                   rocio_pardo_e
# 37              sebastian_fonnegra
# 38                sergiogalvis.art
# 39                   soniarojaspez
# 40                   sophiaprietov
# 41            vicentavictoriagomez
# 42               villamilyvillamil
# 43               catalinaortiz1065
# 44                   danielalopezp
# 45                  feliperomero30
# 46                    juan_covelli
# 47                    juancortes79
# 48                     oldnewflesh
# 49                     silvanuchis
# 50            susanaordonezartista
# 51              vanessanietoromero
# 52                   vivianabtroya
#
#                                              Keywords  \
# 0   [serie, asedio, paisaje, reducido, papel, paso...
# 1   [selva, ser, hombre, mundo, animal, animales, ...
# 2   [cuerpo, haciendo, demás, pregunta, tiempo, de...
# 3   [luz, espacio, lugar, agua, imágenes, dibujos,...
# 4   [escultura, hogar, habitar, espacio, contenido...
# 5   [artista, espacio, bogotá, museo, moreno, hoff...
# 6   [dibujo, naturaleza, paisaje, instalación, cie...
# 7   [tiempo, mundo, imágenes, reloj, biblioteca, a...
# 8   [fotografía, publicaciones, impresiones, serig...
# 9   [barreto, textil, camila, tiempo, dispositivo,...
# 10  [ciudad, caminar, serie, día, foto, tiempo, mi...
# 11  [soliloquio, discursos, amorosos, novela, roma...
# 12  [libros, serie, lugar, memoria, dibujos, objet...
# 13  [china, estudio, fin, cosas, falso, baja, cali...
# 14  [digital, 8, bit, pixel, animación, video, cul...
# 15  [dibujo, nubes, hiperrealismo, realismo, blanc...
# 16  [dibujo, territorio, bordes, artista, susana, ...
# 17  [fotografía, arquitectura, monumentos, dibujo,...
# 18  [arte, digital, sonoro, electrónica, circuitos...
# 19  [vive, si, cada, persona, mundo, nadie, mismo,...
# 20  [hombre, laguna, libros, negocio, pescaditos, ...
# 21  [pinturas, digitalmente, fisica, estetica, heg...
# 22  [través, proyecto, cemento, paisaje, espacios,...
# 23  [gorgona, dibujos, viajes, mítico, construido,...
# 24  [paisaje, línea, horizonte, mediante, fuji, na...
# 25  [lugares, paraíso, gnomos, ciudad, publicación...
# 26  [rayas, papel, si, recta, arte, forma, calle, ...
# 27  [quimeras, diseño, evento, donaciones, pañolet...
# 28  [perros, proyecto, forma, personal, lundi, cer...
# 29  [andrés, valentina, layos, dibujo, vida, artis...
# 30  [dibujo, carbón, estructuras, abstracto, arqui...
# 31  [destino, valientes, publicaciones, paisajes, ...
# 32  [grabado, gráfica, impresión, atlas, mapa, his...
# 33  [espacio, cuerpo, objetos, casa, ser, m, 1, lu...
# 34  [ser, tiempo, hacer, cada, forma, vez, objeto,...
# 35  [fotografía, geometría, urbano, serendipia, en...
# 36  [videoarte, instalación, escultura, análogo, t...
# 37  [trabajo, dibujo, bogotá, fotografía, beca, ar...
# 38  [permite, acero, material, técnicas, consigue,...
# 39  [tiempo, medio, habitantes, barrio, lugar, tep...
# 40  [tatuajes, camisetas, impresiones, serigrafias...
# 41  [vida, lección, medios, plásticos, trabajo, mo...
# 42  [sed, montañas, naturaleza, popular, ornamento...
# 43  [emotional, paper, drawings, life, events, dra...
# 44  [brand, disco, rojo, created, colombia, art, f...
# 45  [undocumented, river, immigrant, police, grave...
# 46  [art, digital, new, space, exhibition, will, o...
# 47  [fusarium, fungus, life, way, laboratory, scie...
# 48  [rengifo, exhibition, everyday, like, kierkega...
# 49  [visual, diary, chromatic, remains, flowers, p...
# 50  [sugarcane, sculpture, guns, handcarved, terri...
# 51  [acid, project, body, act, printmaking, colomb...
# 52  [time, people, waiting, room, space, network, ...
#
#     Average Simil to Text Core  Median Simil to Text Core  Simil top 30
# 0                     0.619336                   0.616342      0.732681
# 1                     0.620930                   0.619647      0.725307
# 2                     0.618375                   0.614423      0.744468
# 3                     0.612733                   0.613017      0.729265
# 4                     0.615642                   0.613963      0.684970
# 5                     0.613428                   0.610498      0.755692
# 6                     0.623523                   0.621949      0.712278
# 7                     0.616998                   0.613740      0.738137
# 8                     0.614018                   0.611329      0.696313
# 9                     0.620611                   0.618642      0.729784
# 10                    0.613930                   0.611123      0.734299
# 11                    0.615337                   0.613621      0.683354
# 12                    0.617079                   0.614032      0.742111
# 13                    0.620565                   0.618578      0.706865
# 14                    0.610030                   0.609162      0.707235
# 15                    0.624115                   0.621312      0.707029
# 16                    0.619523                   0.616313      0.756380
# 17                    0.619750                   0.616407      0.729160
# 18                    0.613211                   0.609695      0.696384
# 19                    0.614097                   0.612635      0.710061
# 20                    0.615670                   0.613886      0.727727
# 21                    0.617585                   0.615347      0.712804
# 22                    0.619615                   0.615449      0.752441
# 23                    0.620313                   0.617470      0.730696
# 24                    0.615449                   0.613339      0.727105
# 25                    0.610016                   0.606799      0.716960
# 26                    0.613794                   0.611765      0.725446
# 27                    0.607281                   0.606589      0.716422
# 28                    0.618264                   0.616235      0.730434
# 29                    0.620975                   0.618264      0.736979
# 30                    0.616513                   0.613497      0.715143
# 31                    0.620671                   0.617413      0.723574
# 32                    0.619655                   0.617505      0.704329
# 33                    0.604567                   0.609573      0.707968
# 34                    0.622812                   0.619138      0.769203
# 35                    0.617803                   0.617024      0.725537
# 36                    0.615279                   0.614473      0.691109
# 37                    0.618570                   0.616477      0.745868
# 38                    0.614585                   0.611675      0.728612
# 39                    0.617322                   0.615109      0.727376
# 40                    0.611862                   0.611141      0.700871
# 41                    0.619133                   0.616298      0.746660
# 42                    0.617694                   0.615472      0.718019
# 43                    0.620984                   0.618719      0.732321
# 44                    0.608544                   0.607259      0.723484
# 45                    0.614441                   0.612468      0.703538
# 46                    0.616454                   0.612816      0.751148
# 47                    0.617318                   0.616563      0.719441
# 48                    0.617044                   0.614171      0.730715
# 49                    0.622938                   0.620901      0.702922
# 50                    0.623115                   0.620609      0.696696
# 51                    0.617238                   0.616072      0.732779
# 52                    0.609873                   0.608430      0.706867

# %%
dfc[['Average Simil to Text Core','Artist']].sort_values(by=['Average Simil to Text Core'], ascending=False).head(10)
# Out:
#     Average Simil to Text Core                Artist
# 15                    0.624115               dacunat
# 6                     0.623523           anibaldo081
# 50                    0.623115  susanaordonezartista
# 49                    0.622938           silvanuchis
# 34                    0.622812           nclsbarrera
# 43                    0.620984     catalinaortiz1065
# 29                    0.620975           layosandres
# 1                     0.620930       agustinalallana
# 31                    0.620671         mayacorredorr
# 9                     0.620611    camilabarretohoyos

# %%
dfc[['Simil top 30','Artist']].sort_values(by=['Simil top 30'], ascending=False).head(10)
# Out:
#     Simil top 30                    Artist
# 34      0.769203               nclsbarrera
# 16      0.756380                ejelejalea
# 5       0.755692   andres_moreno_hoffmannn
# 22      0.752441       fernandaluzavendano
# 46      0.751148              juan_covelli
# 41      0.746660      vicentavictoriagomez
# 37      0.745868        sebastian_fonnegra
# 2       0.744468                  alequint
# 12      0.742111  catalinajaramilloquijano
# 7       0.738137                 aparissio

# %%
dfc['Score Mean TextCorpus'] = dfc['Average Simil to Text Core'].rank(ascending = 0)
dfc['Score Top30'] = dfc['Simil top 30'].rank(ascending = 0)
dfc['Total Text Score'] = dfc['Score Mean TextCorpus'] + dfc['Score Top30'] 
dfc.sort_values(by='Total Text Score')
#df.drop('Text Rank',axis=1, inplace=True)
dfc
# Out:
#                             Artist  \
# 0   adalbertocalvogonzalez_artista
# 1                  agustinalallana
# 2                         alequint
# 3      alexandra_mccormick_artista
# 4                         aliriocc
# 5          andres_moreno_hoffmannn
# 6                      anibaldo081
# 7                        aparissio
# 8                     burningflags
# 9               camilabarretohoyos
# 10                camilacostalzate
# 11                 carolina_diaz_g
# 12        catalinajaramilloquijano
# 13               colectivomonomero
# 14                    crila_regina
# 15                         dacunat
# 16                      ejelejalea
# 17                estebanl_lopez_e
# 18                         faaloon
# 19                    federicopuyo
# 20                felipeuribemejia
# 21                  felipezapataz4
# 22             fernandaluzavendano
# 23         gabrielhernandezserrato
# 24                  guarnizo_david
# 25                   haymuchasanas
# 26                        jpuribem
# 27            juansebastianrosillo
# 28                      klauslundi
# 29                     layosandres
# 30        mauriciojaramilloartista
# 31                   mayacorredorr
# 32                        namejiam
# 33         natalia_castillo_rincon
# 34                     nclsbarrera
# 35                 ojedaenel.lente
# 36                   rocio_pardo_e
# 37              sebastian_fonnegra
# 38                sergiogalvis.art
# 39                   soniarojaspez
# 40                   sophiaprietov
# 41            vicentavictoriagomez
# 42               villamilyvillamil
# 43               catalinaortiz1065
# 44                   danielalopezp
# 45                  feliperomero30
# 46                    juan_covelli
# 47                    juancortes79
# 48                     oldnewflesh
# 49                     silvanuchis
# 50            susanaordonezartista
# 51              vanessanietoromero
# 52                   vivianabtroya
#
#                                              Keywords  \
# 0   [serie, asedio, paisaje, reducido, papel, paso...
# 1   [selva, ser, hombre, mundo, animal, animales, ...
# 2   [cuerpo, haciendo, demás, pregunta, tiempo, de...
# 3   [luz, espacio, lugar, agua, imágenes, dibujos,...
# 4   [escultura, hogar, habitar, espacio, contenido...
# 5   [artista, espacio, bogotá, museo, moreno, hoff...
# 6   [dibujo, naturaleza, paisaje, instalación, cie...
# 7   [tiempo, mundo, imágenes, reloj, biblioteca, a...
# 8   [fotografía, publicaciones, impresiones, serig...
# 9   [barreto, textil, camila, tiempo, dispositivo,...
# 10  [ciudad, caminar, serie, día, foto, tiempo, mi...
# 11  [soliloquio, discursos, amorosos, novela, roma...
# 12  [libros, serie, lugar, memoria, dibujos, objet...
# 13  [china, estudio, fin, cosas, falso, baja, cali...
# 14  [digital, 8, bit, pixel, animación, video, cul...
# 15  [dibujo, nubes, hiperrealismo, realismo, blanc...
# 16  [dibujo, territorio, bordes, artista, susana, ...
# 17  [fotografía, arquitectura, monumentos, dibujo,...
# 18  [arte, digital, sonoro, electrónica, circuitos...
# 19  [vive, si, cada, persona, mundo, nadie, mismo,...
# 20  [hombre, laguna, libros, negocio, pescaditos, ...
# 21  [pinturas, digitalmente, fisica, estetica, heg...
# 22  [través, proyecto, cemento, paisaje, espacios,...
# 23  [gorgona, dibujos, viajes, mítico, construido,...
# 24  [paisaje, línea, horizonte, mediante, fuji, na...
# 25  [lugares, paraíso, gnomos, ciudad, publicación...
# 26  [rayas, papel, si, recta, arte, forma, calle, ...
# 27  [quimeras, diseño, evento, donaciones, pañolet...
# 28  [perros, proyecto, forma, personal, lundi, cer...
# 29  [andrés, valentina, layos, dibujo, vida, artis...
# 30  [dibujo, carbón, estructuras, abstracto, arqui...
# 31  [destino, valientes, publicaciones, paisajes, ...
# 32  [grabado, gráfica, impresión, atlas, mapa, his...
# 33  [espacio, cuerpo, objetos, casa, ser, m, 1, lu...
# 34  [ser, tiempo, hacer, cada, forma, vez, objeto,...
# 35  [fotografía, geometría, urbano, serendipia, en...
# 36  [videoarte, instalación, escultura, análogo, t...
# 37  [trabajo, dibujo, bogotá, fotografía, beca, ar...
# 38  [permite, acero, material, técnicas, consigue,...
# 39  [tiempo, medio, habitantes, barrio, lugar, tep...
# 40  [tatuajes, camisetas, impresiones, serigrafias...
# 41  [vida, lección, medios, plásticos, trabajo, mo...
# 42  [sed, montañas, naturaleza, popular, ornamento...
# 43  [emotional, paper, drawings, life, events, dra...
# 44  [brand, disco, rojo, created, colombia, art, f...
# 45  [undocumented, river, immigrant, police, grave...
# 46  [art, digital, new, space, exhibition, will, o...
# 47  [fusarium, fungus, life, way, laboratory, scie...
# 48  [rengifo, exhibition, everyday, like, kierkega...
# 49  [visual, diary, chromatic, remains, flowers, p...
# 50  [sugarcane, sculpture, guns, handcarved, terri...
# 51  [acid, project, body, act, printmaking, colomb...
# 52  [time, people, waiting, room, space, network, ...
#
#     Average Simil to Text Core  Median Simil to Text Core  Simil top 30  \
# 0                     0.619336                   0.616342      0.732681
# 1                     0.620930                   0.619647      0.725307
# 2                     0.618375                   0.614423      0.744468
# 3                     0.612733                   0.613017      0.729265
# 4                     0.615642                   0.613963      0.684970
# 5                     0.613428                   0.610498      0.755692
# 6                     0.623523                   0.621949      0.712278
# 7                     0.616998                   0.613740      0.738137
# 8                     0.614018                   0.611329      0.696313
# 9                     0.620611                   0.618642      0.729784
# 10                    0.613930                   0.611123      0.734299
# 11                    0.615337                   0.613621      0.683354
# 12                    0.617079                   0.614032      0.742111
# 13                    0.620565                   0.618578      0.706865
# 14                    0.610030                   0.609162      0.707235
# 15                    0.624115                   0.621312      0.707029
# 16                    0.619523                   0.616313      0.756380
# 17                    0.619750                   0.616407      0.729160
# 18                    0.613211                   0.609695      0.696384
# 19                    0.614097                   0.612635      0.710061
# 20                    0.615670                   0.613886      0.727727
# 21                    0.617585                   0.615347      0.712804
# 22                    0.619615                   0.615449      0.752441
# 23                    0.620313                   0.617470      0.730696
# 24                    0.615449                   0.613339      0.727105
# 25                    0.610016                   0.606799      0.716960
# 26                    0.613794                   0.611765      0.725446
# 27                    0.607281                   0.606589      0.716422
# 28                    0.618264                   0.616235      0.730434
# 29                    0.620975                   0.618264      0.736979
# 30                    0.616513                   0.613497      0.715143
# 31                    0.620671                   0.617413      0.723574
# 32                    0.619655                   0.617505      0.704329
# 33                    0.604567                   0.609573      0.707968
# 34                    0.622812                   0.619138      0.769203
# 35                    0.617803                   0.617024      0.725537
# 36                    0.615279                   0.614473      0.691109
# 37                    0.618570                   0.616477      0.745868
# 38                    0.614585                   0.611675      0.728612
# 39                    0.617322                   0.615109      0.727376
# 40                    0.611862                   0.611141      0.700871
# 41                    0.619133                   0.616298      0.746660
# 42                    0.617694                   0.615472      0.718019
# 43                    0.620984                   0.618719      0.732321
# 44                    0.608544                   0.607259      0.723484
# 45                    0.614441                   0.612468      0.703538
# 46                    0.616454                   0.612816      0.751148
# 47                    0.617318                   0.616563      0.719441
# 48                    0.617044                   0.614171      0.730715
# 49                    0.622938                   0.620901      0.702922
# 50                    0.623115                   0.620609      0.696696
# 51                    0.617238                   0.616072      0.732779
# 52                    0.609873                   0.608430      0.706867
#
#     Score Mean TextCorpus  Score Top30  Total Text Score
# 0                    17.0         14.0              31.0
# 1                     8.0         28.0              36.0
# 2                    20.0          8.0              28.0
# 3                    46.0         20.0              66.0
# 4                    34.0         52.0              86.0
# 5                    44.0          3.0              47.0
# 6                     2.0         37.0              39.0
# 7                    30.0         10.0              40.0
# 8                    41.0         50.0              91.0
# 9                    10.0         19.0              29.0
# 10                   42.0         12.0              54.0
# 11                   36.0         53.0              89.0
# 12                   28.0          9.0              37.0
# 13                   11.0         43.0              54.0
# 14                   48.0         40.0              88.0
# 15                    1.0         41.0              42.0
# 16                   16.0          2.0              18.0
# 17                   13.0         21.0              34.0
# 18                   45.0         49.0              94.0
# 19                   40.0         38.0              78.0
# 20                   33.0         23.0              56.0
# 21                   24.0         36.0              60.0
# 22                   15.0          4.0              19.0
# 23                   12.0         17.0              29.0
# 24                   35.0         25.0              60.0
# 25                   49.0         33.0              82.0
# 26                   43.0         27.0              70.0
# 27                   52.0         34.0              86.0
# 28                   21.0         18.0              39.0
# 29                    7.0         11.0              18.0
# 30                   31.0         35.0              66.0
# 31                    9.0         29.0              38.0
# 32                   14.0         44.0              58.0
# 33                   53.0         39.0              92.0
# 34                    5.0          1.0               6.0
# 35                   22.0         26.0              48.0
# 36                   37.0         51.0              88.0
# 37                   19.0          7.0              26.0
# 38                   38.0         22.0              60.0
# 39                   25.0         24.0              49.0
# 40                   47.0         47.0              94.0
# 41                   18.0          6.0              24.0
# 42                   23.0         32.0              55.0
# 43                    6.0         15.0              21.0
# 44                   51.0         30.0              81.0
# 45                   39.0         45.0              84.0
# 46                   32.0          5.0              37.0
# 47                   26.0         31.0              57.0
# 48                   29.0         16.0              45.0
# 49                    4.0         46.0              50.0
# 50                    3.0         48.0              51.0
# 51                   27.0         13.0              40.0
# 52                   50.0         42.0              92.0
